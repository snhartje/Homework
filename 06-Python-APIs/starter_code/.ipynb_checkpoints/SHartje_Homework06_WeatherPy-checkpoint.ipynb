# %% [markdown]
# # WeatherPy
# ----
#
# ### SHartje - Analysis Comments
# * The weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude) where you can see a defined peak in the data.  The Southern hemisphere (positive Latitude values) has a greater variance in temperature than the Northern Hemispshere and it overall appears cooler.  This makes sense considering the tilt of the earth and the fact that the Northern Hemisphere is approaching summer.
# * There is no strong relationship between latitude and humidity.  However, it is interesting that the vast majority of observations have a humidity of over 50%.
# * There doesn't appear to be a strong relationship between latitude and wind speed but there is a slight upward trend as we move further South.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 616

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Save base url
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial" #farenheit and MPH

#Empty list to save the responses and counter variable
weather_json = []
x = 1

#Print initial header for print log
print(f"Beginning Data Retrieval\n---------------------------------")

# Make a request for each of the cities
for city in cities:
    
    try:    
        # Build query URL
        query_url = f"{url}appid={api_key}&q={city}&units={units}"

        # Get one of the posts
        post_response = requests.get(query_url)

        # Save post's JSON
        weather_json.append(post_response.json())

        # Create print log
        print(f"Processing Record {x} | {city}")
        x = x+1

    except:
        print("Missing field/result... skipping.")
# Out:
# Beginning Data Retrieval
# ---------------------------------
# Processing Record 1 | zharkent
# Processing Record 2 | hamilton
# Processing Record 3 | minas de barroteran
# Processing Record 4 | thompson
# Processing Record 5 | hearst
# Processing Record 6 | maloy
# Processing Record 7 | ahuimanu
# Processing Record 8 | ushuaia
# Processing Record 9 | yellowknife
# Processing Record 10 | nemetker
# Processing Record 11 | ancud
# Processing Record 12 | punta arenas
# Processing Record 13 | vaini
# Processing Record 14 | albany
# Processing Record 15 | nacala
# Processing Record 16 | lebu
# Processing Record 17 | rikitea
# Processing Record 18 | hithadhoo
# Processing Record 19 | busselton
# Processing Record 20 | harper
# Processing Record 21 | pisco
# Processing Record 22 | khatanga
# Processing Record 23 | jamestown
# Processing Record 24 | graaff-reinet
# Processing Record 25 | husavik
# Processing Record 26 | butaritari
# Processing Record 27 | kodiak
# Processing Record 28 | port hardy
# Processing Record 29 | salalah
# Processing Record 30 | marcona
# Processing Record 31 | melenci
# Processing Record 32 | dinklage
# Processing Record 33 | kabalo
# Processing Record 34 | illoqqortoormiut
# Processing Record 35 | ribeira grande
# Processing Record 36 | kamenskoye
# Processing Record 37 | nome
# Processing Record 38 | bluff
# Processing Record 39 | attawapiskat
# Processing Record 40 | mahebourg
# Processing Record 41 | coahuayana
# Processing Record 42 | chokurdakh
# Processing Record 43 | raudeberg
# Processing Record 44 | asau
# Processing Record 45 | labuan
# Processing Record 46 | sur
# Processing Record 47 | wagar
# Processing Record 48 | berlevag
# Processing Record 49 | arraial do cabo
# Processing Record 50 | meadow lake
# Processing Record 51 | belaya gora
# Processing Record 52 | abiy adi
# Processing Record 53 | victoria
# Processing Record 54 | cape town
# Processing Record 55 | mataura
# Processing Record 56 | atambua
# Processing Record 57 | bahia blanca
# Processing Record 58 | sedelnikovo
# Processing Record 59 | kaeo
# Processing Record 60 | kaitangata
# Processing Record 61 | hermanus
# Processing Record 62 | mys shmidta
# Processing Record 63 | narsaq
# Processing Record 64 | dolinsk
# Processing Record 65 | palabuhanratu
# Processing Record 66 | tabiauea
# Processing Record 67 | kahului
# Processing Record 68 | aksarka
# Processing Record 69 | torbay
# Processing Record 70 | sentyabrskiy
# Processing Record 71 | chatellerault
# Processing Record 72 | rafaela
# Processing Record 73 | puerto ayora
# Processing Record 74 | santa fe
# Processing Record 75 | biak
# Processing Record 76 | wuwei
# Processing Record 77 | mayumba
# Processing Record 78 | port hedland
# Processing Record 79 | adilcevaz
# Processing Record 80 | hobart
# Processing Record 81 | mehamn
# Processing Record 82 | taolanaro
# Processing Record 83 | bagan
# Processing Record 84 | high level
# Processing Record 85 | sorbhog
# Processing Record 86 | dikson
# Processing Record 87 | iralaya
# Processing Record 88 | tabuk
# Processing Record 89 | atuona
# Processing Record 90 | dunedin
# Processing Record 91 | kidal
# Processing Record 92 | nanortalik
# Processing Record 93 | zhigansk
# Processing Record 94 | tual
# Processing Record 95 | constitucion
# Processing Record 96 | georgetown
# Processing Record 97 | chichica
# Processing Record 98 | hilo
# Processing Record 99 | flinders
# Processing Record 100 | sistranda
# Processing Record 101 | yeniseysk
# Processing Record 102 | bengkulu
# Processing Record 103 | bethel
# Processing Record 104 | amderma
# Processing Record 105 | saskylakh
# Processing Record 106 | boende
# Processing Record 107 | gat
# Processing Record 108 | lagoa
# Processing Record 109 | soligalich
# Processing Record 110 | guerrero negro
# Processing Record 111 | tuatapere
# Processing Record 112 | tshikapa
# Processing Record 113 | santa catalina
# Processing Record 114 | karkaralinsk
# Processing Record 115 | meyungs
# Processing Record 116 | mar del plata
# Processing Record 117 | castro
# Processing Record 118 | qaqortoq
# Processing Record 119 | tres picos
# Processing Record 120 | tuktoyaktuk
# Processing Record 121 | geraldton
# Processing Record 122 | oktyabrskiy
# Processing Record 123 | los llanos de aridane
# Processing Record 124 | morondava
# Processing Record 125 | bredasdorp
# Processing Record 126 | port lincoln
# Processing Record 127 | konya
# Processing Record 128 | saldanha
# Processing Record 129 | kapaa
# Processing Record 130 | carnarvon
# Processing Record 131 | hualmay
# Processing Record 132 | southbridge
# Processing Record 133 | chapais
# Processing Record 134 | majene
# Processing Record 135 | aanekoski
# Processing Record 136 | tanout
# Processing Record 137 | kamenka
# Processing Record 138 | upernavik
# Processing Record 139 | qeshm
# Processing Record 140 | mecca
# Processing Record 141 | woodward
# Processing Record 142 | warqla
# Processing Record 143 | new norfolk
# Processing Record 144 | wuning
# Processing Record 145 | port alfred
# Processing Record 146 | cabo san lucas
# Processing Record 147 | provost
# Processing Record 148 | vaitupu
# Processing Record 149 | east london
# Processing Record 150 | bambous virieux
# Processing Record 151 | saint george
# Processing Record 152 | tsihombe
# Processing Record 153 | dolbeau
# Processing Record 154 | saleaula
# Processing Record 155 | ballitoville
# Processing Record 156 | tsimlyansk
# Processing Record 157 | rakitnoye
# Processing Record 158 | huaiyin
# Processing Record 159 | tiksi
# Processing Record 160 | anadyr
# Processing Record 161 | charters towers
# Processing Record 162 | namibe
# Processing Record 163 | faanui
# Processing Record 164 | puerto leguizamo
# Processing Record 165 | alekseyevsk
# Processing Record 166 | krasnovishersk
# Processing Record 167 | burdur
# Processing Record 168 | rolla
# Processing Record 169 | rolim de moura
# Processing Record 170 | barrow
# Processing Record 171 | svetlaya
# Processing Record 172 | dubbo
# Processing Record 173 | korla
# Processing Record 174 | port elizabeth
# Processing Record 175 | tasiilaq
# Processing Record 176 | nizhniy odes
# Processing Record 177 | avarua
# Processing Record 178 | saint-philippe
# Processing Record 179 | kavieng
# Processing Record 180 | coos bay
# Processing Record 181 | fairbanks
# Processing Record 182 | port augusta
# Processing Record 183 | egvekinot
# Processing Record 184 | yevlax
# Processing Record 185 | provideniya
# Processing Record 186 | baruun-urt
# Processing Record 187 | kachiry
# Processing Record 188 | povolzhskiy
# Processing Record 189 | isangel
# Processing Record 190 | laguna
# Processing Record 191 | sungaipenuh
# Processing Record 192 | qaanaaq
# Processing Record 193 | pevek
# Processing Record 194 | baghdad
# Processing Record 195 | brae
# Processing Record 196 | kamsack
# Processing Record 197 | portland
# Processing Record 198 | sohag
# Processing Record 199 | moree
# Processing Record 200 | maningrida
# Processing Record 201 | velyka oleksandrivka
# Processing Record 202 | awjilah
# Processing Record 203 | banjar
# Processing Record 204 | campbell river
# Processing Record 205 | concarneau
# Processing Record 206 | fukue
# Processing Record 207 | vila franca do campo
# Processing Record 208 | maputo
# Processing Record 209 | mau
# Processing Record 210 | gashua
# Processing Record 211 | najran
# Processing Record 212 | longyearbyen
# Processing Record 213 | ostrovnoy
# Processing Record 214 | shenjiamen
# Processing Record 215 | esperance
# Processing Record 216 | ponta do sol
# Processing Record 217 | hunchun
# Processing Record 218 | tiznit
# Processing Record 219 | okitipupa
# Processing Record 220 | bandarbeyla
# Processing Record 221 | kyzyl-suu
# Processing Record 222 | padang
# Processing Record 223 | zachagansk
# Processing Record 224 | sartell
# Processing Record 225 | paamiut
# Processing Record 226 | pestretsy
# Processing Record 227 | paso de carrasco
# Processing Record 228 | seoul
# Processing Record 229 | samusu
# Processing Record 230 | pokhara
# Processing Record 231 | ailigandi
# Processing Record 232 | sept-iles
# Processing Record 233 | ambon
# Processing Record 234 | sibu
# Processing Record 235 | te anau
# Processing Record 236 | jalu
# Processing Record 237 | bose
# Processing Record 238 | millau
# Processing Record 239 | dahra
# Processing Record 240 | roebourne
# Processing Record 241 | novikovo
# Processing Record 242 | verkhnyaya inta
# Processing Record 243 | nizhneyansk
# Processing Record 244 | xadani
# Processing Record 245 | sao felix do xingu
# Processing Record 246 | oyama
# Processing Record 247 | biltine
# Processing Record 248 | lavrentiya
# Processing Record 249 | saint-francois
# Processing Record 250 | severo-kurilsk
# Processing Record 251 | taltal
# Processing Record 252 | grindavik
# Processing Record 253 | kelo
# Processing Record 254 | batemans bay
# Processing Record 255 | fort nelson
# Processing Record 256 | san luis
# Processing Record 257 | kondinskoye
# Processing Record 258 | verkhnevilyuysk
# Processing Record 259 | cidreira
# Processing Record 260 | anyksciai
# Processing Record 261 | tomatlan
# Processing Record 262 | salinas
# Processing Record 263 | ust-ilimsk
# Processing Record 264 | hue
# Processing Record 265 | jardim
# Processing Record 266 | tecpan
# Processing Record 267 | lorengau
# Processing Record 268 | ladozhskaya
# Processing Record 269 | dzhebariki-khaya
# Processing Record 270 | kushiro
# Processing Record 271 | belushya guba
# Processing Record 272 | talaya
# Processing Record 273 | maragogi
# Processing Record 274 | whittlesea
# Processing Record 275 | mananjary
# Processing Record 276 | san cristobal
# Processing Record 277 | marzuq
# Processing Record 278 | roma
# Processing Record 279 | olafsvik
# Processing Record 280 | chuy
# Processing Record 281 | narragansett
# Processing Record 282 | talnakh
# Processing Record 283 | bestobe
# Processing Record 284 | hvolsvollur
# Processing Record 285 | alice springs
# Processing Record 286 | abbeville
# Processing Record 287 | salym
# Processing Record 288 | moshenskoye
# Processing Record 289 | clyde river
# Processing Record 290 | fortuna
# Processing Record 291 | mullaitivu
# Processing Record 292 | lata
# Processing Record 293 | simi
# Processing Record 294 | maplewood
# Processing Record 295 | mayo
# Processing Record 296 | leighton buzzard
# Processing Record 297 | pisz
# Processing Record 298 | iqaluit
# Processing Record 299 | nikolskoye
# Processing Record 300 | saint-pierre
# Processing Record 301 | kushima
# Processing Record 302 | duminichi
# Processing Record 303 | gold coast
# Processing Record 304 | oksbol
# Processing Record 305 | gravdal
# Processing Record 306 | dakar
# Processing Record 307 | chauk
# Processing Record 308 | mandalgovi
# Processing Record 309 | wladyslawowo
# Processing Record 310 | georgiyevka
# Processing Record 311 | pacific grove
# Processing Record 312 | monteagudo
# Processing Record 313 | beloha
# Processing Record 314 | glyadyanskoye
# Processing Record 315 | mount isa
# Processing Record 316 | dinguiraye
# Processing Record 317 | bay roberts
# Processing Record 318 | san policarpo
# Processing Record 319 | maraba
# Processing Record 320 | pundaguitan
# Processing Record 321 | san patricio
# Processing Record 322 | mirabad
# Processing Record 323 | halalo
# Processing Record 324 | klaksvik
# Processing Record 325 | yumen
# Processing Record 326 | iquitos
# Processing Record 327 | shar
# Processing Record 328 | hasaki
# Processing Record 329 | huarmey
# Processing Record 330 | santa rosa
# Processing Record 331 | beira
# Processing Record 332 | ucluelet
# Processing Record 333 | jishou
# Processing Record 334 | kemi
# Processing Record 335 | annau
# Processing Record 336 | chilliwack
# Processing Record 337 | ilulissat
# Processing Record 338 | kavaratti
# Processing Record 339 | bayeux
# Processing Record 340 | rocha
# Processing Record 341 | chaykovskiy
# Processing Record 342 | yerbogachen
# Processing Record 343 | lermontovka
# Processing Record 344 | burica
# Processing Record 345 | barentsburg
# Processing Record 346 | kampong thum
# Processing Record 347 | kimbe
# Processing Record 348 | cedar city
# Processing Record 349 | owo
# Processing Record 350 | moundsville
# Processing Record 351 | yanan
# Processing Record 352 | la seyne-sur-mer
# Processing Record 353 | chapayeve
# Processing Record 354 | chagda
# Processing Record 355 | umm lajj
# Processing Record 356 | christchurch
# Processing Record 357 | tilichiki
# Processing Record 358 | lompoc
# Processing Record 359 | hadejia
# Processing Record 360 | norwich
# Processing Record 361 | vardo
# Processing Record 362 | souillac
# Processing Record 363 | nguruka
# Processing Record 364 | alofi
# Processing Record 365 | buala
# Processing Record 366 | liverpool
# Processing Record 367 | srednekolymsk
# Processing Record 368 | mbeya
# Processing Record 369 | lasa
# Processing Record 370 | touros
# Processing Record 371 | ust-tsilma
# Processing Record 372 | necochea
# Processing Record 373 | mezica
# Processing Record 374 | mariental
# Processing Record 375 | gizo
# Processing Record 376 | dumas
# Processing Record 377 | kupang
# Processing Record 378 | kedrovyy
# Processing Record 379 | kappeln
# Processing Record 380 | do gonbadan
# Processing Record 381 | karratha
# Processing Record 382 | sekoma
# Processing Record 383 | ullapool
# Processing Record 384 | roald
# Processing Record 385 | ondjiva
# Processing Record 386 | airai
# Processing Record 387 | odweyne
# Processing Record 388 | tamandare
# Processing Record 389 | muroto
# Processing Record 390 | mount gambier
# Processing Record 391 | nouadhibou
# Processing Record 392 | hirara
# Processing Record 393 | toliary
# Processing Record 394 | ambilobe
# Processing Record 395 | san vicente
# Processing Record 396 | porto nacional
# Processing Record 397 | camana
# Processing Record 398 | sao desiderio
# Processing Record 399 | kaniama
# Processing Record 400 | dafeng
# Processing Record 401 | pangkalanbuun
# Processing Record 402 | tabou
# Processing Record 403 | abu samrah
# Processing Record 404 | vao
# Processing Record 405 | kruisfontein
# Processing Record 406 | ostringen
# Processing Record 407 | mareeba
# Processing Record 408 | norman wells
# Processing Record 409 | guiratinga
# Processing Record 410 | tura
# Processing Record 411 | buchanan
# Processing Record 412 | kroya
# Processing Record 413 | esna
# Processing Record 414 | bundaberg
# Processing Record 415 | ilhabela
# Processing Record 416 | leningradskiy
# Processing Record 417 | tolmin
# Processing Record 418 | maceio
# Processing Record 419 | ahipara
# Processing Record 420 | college
# Processing Record 421 | verkhoyansk
# Processing Record 422 | kirando
# Processing Record 423 | ayagoz
# Processing Record 424 | fraga
# Processing Record 425 | makaha
# Processing Record 426 | komsomolskiy
# Processing Record 427 | ojinaga
# Processing Record 428 | dryden
# Processing Record 429 | neepawa
# Processing Record 430 | moron
# Processing Record 431 | leh
# Processing Record 432 | tanete
# Processing Record 433 | hovd
# Processing Record 434 | semirom
# Processing Record 435 | kargasok
# Processing Record 436 | lahat
# Processing Record 437 | grand river south east
# Processing Record 438 | nishihara
# Processing Record 439 | katsuura
# Processing Record 440 | olinda
# Processing Record 441 | balimo
# Processing Record 442 | lakes entrance
# Processing Record 443 | sharjah
# Processing Record 444 | praya
# Processing Record 445 | buraydah
# Processing Record 446 | carupano
# Processing Record 447 | oudtshoorn
# Processing Record 448 | tambovka
# Processing Record 449 | goderich
# Processing Record 450 | bilopillya
# Processing Record 451 | misterbianco
# Processing Record 452 | lufilufi
# Processing Record 453 | novobiryusinskiy
# Processing Record 454 | uinskoye
# Processing Record 455 | paragominas
# Processing Record 456 | bairnsdale
# Processing Record 457 | baykit
# Processing Record 458 | brownsville
# Processing Record 459 | mitsamiouli
# Processing Record 460 | dalinghe
# Processing Record 461 | havoysund
# Processing Record 462 | port blair
# Processing Record 463 | dubai
# Processing Record 464 | arman
# Processing Record 465 | codrington
# Processing Record 466 | seymchan
# Processing Record 467 | sayyan
# Processing Record 468 | piacabucu
# Processing Record 469 | pyaozerskiy
# Processing Record 470 | wukari
# Processing Record 471 | aykhal
# Processing Record 472 | inhambane
# Processing Record 473 | nara
# Processing Record 474 | japura
# Processing Record 475 | rapid valley
# Processing Record 476 | sinkat
# Processing Record 477 | iberia
# Processing Record 478 | butembo
# Processing Record 479 | kendari
# Processing Record 480 | severo-yeniseyskiy
# Processing Record 481 | ixhuatan
# Processing Record 482 | aksu
# Processing Record 483 | buqayq
# Processing Record 484 | ulaanbaatar
# Processing Record 485 | phayakkhaphum phisai
# Processing Record 486 | neftcala
# Processing Record 487 | dawlatabad
# Processing Record 488 | sabha
# Processing Record 489 | vijayapuri
# Processing Record 490 | vidim
# Processing Record 491 | umzimvubu
# Processing Record 492 | manggar
# Processing Record 493 | iskateley
# Processing Record 494 | cherskiy
# Processing Record 495 | dezhou
# Processing Record 496 | susanville
# Processing Record 497 | asyut
# Processing Record 498 | sao gabriel da cachoeira
# Processing Record 499 | flin flon
# Processing Record 500 | nikolsk
# Processing Record 501 | bronnoysund
# Processing Record 502 | sao filipe
# Processing Record 503 | hambantota
# Processing Record 504 | oussouye
# Processing Record 505 | tullahoma
# Processing Record 506 | waddan
# Processing Record 507 | bolsheustikinskoye
# Processing Record 508 | zyryanka
# Processing Record 509 | santiago del estero
# Processing Record 510 | turukhansk
# Processing Record 511 | goure
# Processing Record 512 | galiwinku
# Processing Record 513 | dhidhdhoo
# Processing Record 514 | yulara
# Processing Record 515 | pochutla
# Processing Record 516 | ellensburg
# Processing Record 517 | kang
# Processing Record 518 | broome
# Processing Record 519 | mackay
# Processing Record 520 | asfi
# Processing Record 521 | lagos
# Processing Record 522 | brigantine
# Processing Record 523 | celestun
# Processing Record 524 | mazyr
# Processing Record 525 | mansehra
# Processing Record 526 | mwinilunga
# Processing Record 527 | jaffna
# Processing Record 528 | badvel
# Processing Record 529 | antalaha
# Processing Record 530 | portobelo
# Processing Record 531 | taoudenni
# Processing Record 532 | beyneu
# Processing Record 533 | manakara
# Processing Record 534 | murdochville
# Processing Record 535 | avera
# Processing Record 536 | katobu
# Processing Record 537 | conceicao do araguaia
# Processing Record 538 | linshu
# Processing Record 539 | cayenne
# Processing Record 540 | coihaique
# Processing Record 541 | ixtapa
# Processing Record 542 | caravelas
# Processing Record 543 | lar
# Processing Record 544 | tabas
# Processing Record 545 | tessalit
# Processing Record 546 | tazovskiy
# Processing Record 547 | quatre cocos
# Processing Record 548 | qingan
# Processing Record 549 | ati
# Processing Record 550 | kangaatsiaq
# Processing Record 551 | rairangpur
# Processing Record 552 | staryy nadym
# Processing Record 553 | jamame
# Processing Record 554 | taksimo
# Processing Record 555 | fort saint james
# Processing Record 556 | namatanai
# Processing Record 557 | san jose
# Processing Record 558 | caluquembe
# Processing Record 559 | boa vista
# Processing Record 560 | poronaysk
# Processing Record 561 | siddapur
# Processing Record 562 | mahadday weyne
# Processing Record 563 | rindal
# Processing Record 564 | xingyi
# Processing Record 565 | dongsheng
# Processing Record 566 | dianopolis
# Processing Record 567 | maracanau
# Processing Record 568 | mosbach
# Processing Record 569 | mega
# Processing Record 570 | trairi
# Processing Record 571 | rawson
# Processing Record 572 | wanning
# Processing Record 573 | sola
# Processing Record 574 | tlalnepantla
# Processing Record 575 | saryshagan
# Processing Record 576 | bolungarvik
# Processing Record 577 | maibong
# Processing Record 578 | byron bay
# Processing Record 579 | kondagaon
# Processing Record 580 | adre
# Processing Record 581 | vilhena
# Processing Record 582 | poum
# Processing Record 583 | haines junction
# Processing Record 584 | tyrma
# Processing Record 585 | lima
# Processing Record 586 | bilma
# Processing Record 587 | aklavik
# Processing Record 588 | suhbaatar
# Processing Record 589 | nichinan
# Processing Record 590 | conceicao da barra
# Processing Record 591 | waipawa
# Processing Record 592 | pringsewu
# Processing Record 593 | kot putli
# Processing Record 594 | nuuk
# Processing Record 595 | arbuzynka
# Processing Record 596 | townsville
# Processing Record 597 | pangody
# Processing Record 598 | nzega
# Processing Record 599 | honningsvag
# Processing Record 600 | sotouboua
# Processing Record 601 | ikalamavony
# Processing Record 602 | yar-sale
# Processing Record 603 | fort-shevchenko
# Processing Record 604 | plonsk
# Processing Record 605 | cap-aux-meules
# Processing Record 606 | port keats
# Processing Record 607 | tasbuget
# Processing Record 608 | verkhnetulomskiy
# Processing Record 609 | pingzhuang
# Processing Record 610 | rungata
# Processing Record 611 | negara
# Processing Record 612 | isiro
# Processing Record 613 | kuche
# Processing Record 614 | launceston
# Processing Record 615 | middelburg
# Processing Record 616 | rabo de peixe

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Show weather_json to understand how to pull out data
weather_json
# Out:
# [{'coord': {'lon': 80, 'lat': 44.17},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02n'}],
#   'base': 'stations',
#   'main': {'temp': 29.12,
#    'pressure': 1023.54,
#    'humidity': 68,
#    'temp_min': 29.12,
#    'temp_max': 29.12,
#    'sea_level': 1023.54,
#    'grnd_level': 827.66},
#   'wind': {'speed': 1.03, 'deg': 335.504},
#   'clouds': {'all': 20},
#   'dt': 1554569701,
#   'sys': {'message': 0.0034,
#    'country': 'KZ',
#    'sunrise': 1554509593,
#    'sunset': 1554556293},
#   'id': 1520253,
#   'name': 'Zharkent',
#   'cod': 200},
#  {'coord': {'lon': -64.78, 'lat': 32.3},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 68.88,
#    'pressure': 1024,
#    'humidity': 77,
#    'temp_min': 68,
#    'temp_max': 69.8},
#   'visibility': 10000,
#   'wind': {'speed': 19.46, 'deg': 90},
#   'clouds': {'all': 75},
#   'dt': 1554568325,
#   'sys': {'type': 1,
#    'id': 8816,
#    'message': 0.004,
#    'country': 'BM',
#    'sunrise': 1554544867,
#    'sunset': 1554590499},
#   'id': 3573197,
#   'name': 'Hamilton',
#   'cod': 200},
#  {'coord': {'lon': -101.28, 'lat': 27.63},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 84.2,
#    'pressure': 1008.98,
#    'humidity': 38,
#    'temp_min': 84.2,
#    'temp_max': 84.2,
#    'sea_level': 1008.98,
#    'grnd_level': 946.3},
#   'wind': {'speed': 5.61, 'deg': 1.00403},
#   'clouds': {'all': 0},
#   'dt': 1554569444,
#   'sys': {'message': 0.003,
#    'country': 'MX',
#    'sunrise': 1554553800,
#    'sunset': 1554599083},
#   'id': 3977811,
#   'name': 'Minas de Barroteran',
#   'cod': 200},
#  {'coord': {'lon': -97.86, 'lat': 55.74},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'base': 'stations',
#   'main': {'temp': 21.2,
#    'pressure': 1021,
#    'humidity': 31,
#    'temp_min': 21.2,
#    'temp_max': 21.2},
#   'visibility': 24140,
#   'wind': {'speed': 4.7, 'deg': 30},
#   'clouds': {'all': 20},
#   'dt': 1554566400,
#   'sys': {'type': 1,
#    'id': 935,
#    'message': 0.0042,
#    'country': 'CA',
#    'sunrise': 1554551366,
#    'sunset': 1554599875},
#   'id': 6165406,
#   'name': 'Thompson',
#   'cod': 200},
#  {'coord': {'lon': -83.67, 'lat': 49.69},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 32.9,
#    'pressure': 1023.42,
#    'humidity': 58,
#    'temp_min': 32.9,
#    'temp_max': 32.9,
#    'sea_level': 1023.42,
#    'grnd_level': 997.42},
#   'wind': {'speed': 3.71, 'deg': 313.504},
#   'clouds': {'all': 0},
#   'dt': 1554569475,
#   'sys': {'message': 0.003,
#    'country': 'CA',
#    'sunrise': 1554548469,
#    'sunset': 1554595962},
#   'id': 5973108,
#   'name': 'Hearst',
#   'cod': 200},
#  {'coord': {'lon': 118.1, 'lat': 1},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02n'}],
#   'base': 'stations',
#   'main': {'temp': 75.2,
#    'pressure': 1010.5,
#    'humidity': 89,
#    'temp_min': 75.2,
#    'temp_max': 75.2,
#    'sea_level': 1010.5,
#    'grnd_level': 995.42},
#   'wind': {'speed': 2.15, 'deg': 33.504},
#   'clouds': {'all': 12},
#   'dt': 1554569701,
#   'sys': {'message': 0.0062,
#    'country': 'ID',
#    'sunrise': 1554588355,
#    'sunset': 1554632012},
#   'id': 1628757,
#   'name': 'Maloy',
#   'cod': 200},
#  {'coord': {'lon': -157.84, 'lat': 21.44},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 65.26,
#    'pressure': 1016,
#    'humidity': 82,
#    'temp_min': 62.6,
#    'temp_max': 66.99},
#   'visibility': 16093,
#   'wind': {'speed': 4.61, 'deg': 328.004},
#   'clouds': {'all': 75},
#   'dt': 1554569526,
#   'sys': {'type': 1,
#    'id': 7877,
#    'message': 0.0038,
#    'country': 'US',
#    'sunrise': 1554567581,
#    'sunset': 1554612445},
#   'id': 5856516,
#   'name': 'Ahuimanu',
#   'cod': 200},
#  {'coord': {'lon': -68.31, 'lat': -54.81},
#   'weather': [{'id': 520,
#     'main': 'Rain',
#     'description': 'light intensity shower rain',
#     'icon': '09d'}],
#   'base': 'stations',
#   'main': {'temp': 38.21,
#    'pressure': 986,
#    'humidity': 69,
#    'temp_min': 37.4,
#    'temp_max': 39.2},
#   'visibility': 8000,
#   'wind': {'speed': 23.04, 'deg': 230, 'gust': 15.4},
#   'clouds': {'all': 90},
#   'dt': 1554566400,
#   'sys': {'type': 1,
#    'id': 8303,
#    'message': 0.0045,
#    'country': 'AR',
#    'sunrise': 1554548781,
#    'sunset': 1554588279},
#   'id': 3833367,
#   'name': 'Ushuaia',
#   'cod': 200},
#  {'coord': {'lon': -114.38, 'lat': 62.45},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 9.64,
#    'pressure': 1015,
#    'humidity': 60,
#    'temp_min': 6.01,
#    'temp_max': 12.99},
#   'visibility': 24140,
#   'wind': {'speed': 11.41, 'deg': 90},
#   'clouds': {'all': 75},
#   'dt': 1554568770,
#   'sys': {'type': 1,
#    'id': 1007,
#    'message': 0.0038,
#    'country': 'CA',
#    'sunrise': 1554554528,
#    'sunset': 1554604642},
#   'id': 6185377,
#   'name': 'Yellowknife',
#   'cod': 200},
#  {'coord': {'lon': 18.76, 'lat': 46.72},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 51.53,
#    'pressure': 1007.62,
#    'humidity': 69,
#    'temp_min': 51.53,
#    'temp_max': 51.53,
#    'sea_level': 1007.62,
#    'grnd_level': 991.18},
#   'wind': {'speed': 2.48, 'deg': 192.504},
#   'clouds': {'all': 0},
#   'dt': 1554569702,
#   'sys': {'message': 0.0039,
#    'country': 'HU',
#    'sunrise': 1554524120,
#    'sunset': 1554571155},
#   'id': 3047373,
#   'name': 'Nemetker',
#   'cod': 200},
#  {'coord': {'lon': -73.83, 'lat': -41.87},
#   'weather': [{'id': 701,
#     'main': 'Mist',
#     'description': 'mist',
#     'icon': '50d'}],
#   'base': 'stations',
#   'main': {'temp': 53.6,
#    'pressure': 1020,
#    'humidity': 93,
#    'temp_min': 53.6,
#    'temp_max': 53.6},
#   'visibility': 5000,
#   'wind': {'speed': 18.34, 'deg': 10},
#   'clouds': {'all': 90},
#   'dt': 1554566400,
#   'sys': {'type': 1,
#    'id': 8512,
#    'message': 0.0033,
#    'country': 'CL',
#    'sunrise': 1554549374,
#    'sunset': 1554590335},
#   'id': 3899695,
#   'name': 'Ancud',
#   'cod': 200},
#  {'coord': {'lon': -70.91, 'lat': -53.16},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 48.09,
#    'pressure': 994,
#    'humidity': 89,
#    'temp_min': 48,
#    'temp_max': 48.2},
#   'visibility': 10000,
#   'wind': {'speed': 49.44, 'deg': 250, 'gust': 29.3},
#   'clouds': {'all': 40},
#   'dt': 1554568958,
#   'sys': {'type': 1,
#    'id': 8487,
#    'message': 0.0034,
#    'country': 'CL',
#    'sunrise': 1554549290,
#    'sunset': 1554589019},
#   'id': 3874787,
#   'name': 'Punta Arenas',
#   'cod': 200},
#  {'coord': {'lon': 74.49, 'lat': 15.34},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 71.24,
#    'pressure': 1011.26,
#    'humidity': 76,
#    'temp_min': 71.24,
#    'temp_max': 71.24,
#    'sea_level': 1011.26,
#    'grnd_level': 947.42},
#   'wind': {'speed': 2.71, 'deg': 263.004},
#   'clouds': {'all': 0},
#   'dt': 1554569102,
#   'sys': {'message': 0.0044,
#    'country': 'IN',
#    'sunrise': 1554512043,
#    'sunset': 1554556487},
#   'id': 1273574,
#   'name': 'Vaini',
#   'cod': 200},
#  {'coord': {'lon': -73.75, 'lat': 42.65},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'base': 'stations',
#   'main': {'temp': 47.19,
#    'pressure': 1023,
#    'humidity': 66,
#    'temp_min': 41,
#    'temp_max': 51.01},
#   'visibility': 16093,
#   'wind': {'speed': 5.95, 'deg': 295.004},
#   'rain': {'1h': 0.25},
#   'clouds': {'all': 90},
#   'dt': 1554569431,
#   'sys': {'type': 1,
#    'id': 3273,
#    'message': 0.0054,
#    'country': 'US',
#    'sunrise': 1554546533,
#    'sunset': 1554593138},
#   'id': 5106834,
#   'name': 'Albany',
#   'cod': 200},
#  {'coord': {'lon': 40.69, 'lat': -14.56},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 83.3,
#    'pressure': 1013.82,
#    'humidity': 92,
#    'temp_min': 83.3,
#    'temp_max': 83.3,
#    'sea_level': 1013.82,
#    'grnd_level': 1011.9},
#   'wind': {'speed': 9.31, 'deg': 154.504},
#   'clouds': {'all': 44},
#   'dt': 1554569702,
#   'sys': {'message': 0.0039,
#    'country': 'MZ',
#    'sunrise': 1554520963,
#    'sunset': 1554563788},
#   'id': 1035025,
#   'name': 'Nacala',
#   'cod': 200},
#  {'coord': {'lon': 38.73, 'lat': 8.96},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 61.52,
#    'pressure': 1010.1,
#    'humidity': 59,
#    'temp_min': 61.52,
#    'temp_max': 61.52,
#    'sea_level': 1010.1,
#    'grnd_level': 768.54},
#   'wind': {'speed': 7.85, 'deg': 83.004},
#   'clouds': {'all': 0},
#   'dt': 1554569142,
#   'sys': {'message': 0.0033,
#    'country': 'ET',
#    'sunrise': 1554520803,
#    'sunset': 1554564888},
#   'id': 344979,
#   'name': 'Lebu',
#   'cod': 200},
#  {'coord': {'lon': -134.97, 'lat': -23.12},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 77.27,
#    'pressure': 1018.06,
#    'humidity': 100,
#    'temp_min': 77.27,
#    'temp_max': 77.27,
#    'sea_level': 1018.06,
#    'grnd_level': 1017.98},
#   'wind': {'speed': 14.67, 'deg': 102.004},
#   'clouds': {'all': 76},
#   'dt': 1554568837,
#   'sys': {'message': 0.0037,
#    'country': 'PF',
#    'sunrise': 1554563375,
#    'sunset': 1554605676},
#   'id': 4030556,
#   'name': 'Rikitea',
#   'cod': 200},
#  {'coord': {'lon': 73.08, 'lat': -0.6},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 84.29,
#    'pressure': 1012.54,
#    'humidity': 100,
#    'temp_min': 84.29,
#    'temp_max': 84.29,
#    'sea_level': 1012.54,
#    'grnd_level': 1012.54},
#   'wind': {'speed': 6.17, 'deg': 343.004},
#   'clouds': {'all': 44},
#   'dt': 1554569126,
#   'sys': {'message': 0.003,
#    'country': 'MV',
#    'sunrise': 1554512819,
#    'sunset': 1554556388},
#   'id': 1282256,
#   'name': 'Hithadhoo',
#   'cod': 200},
#  {'coord': {'lon': 115.35, 'lat': -33.64},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 52,
#    'pressure': 1015,
#    'humidity': 53,
#    'temp_min': 50,
#    'temp_max': 55},
#   'wind': {'speed': 10.42, 'deg': 171.504},
#   'rain': {'3h': 0.0075},
#   'clouds': {'all': 76},
#   'dt': 1554568885,
#   'sys': {'type': 3,
#    'id': 2011706,
#    'message': 0.004,
#    'country': 'AU',
#    'sunrise': 1554590062,
#    'sunset': 1554631625},
#   'id': 2075265,
#   'name': 'Busselton',
#   'cod': 200},
#  {'coord': {'lon': -99.24, 'lat': 30.3},
#   'weather': [{'id': 211,
#     'main': 'Thunderstorm',
#     'description': 'thunderstorm',
#     'icon': '11d'},
#    {'id': 721, 'main': 'Haze', 'description': 'haze', 'icon': '50d'},
#    {'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}],
#   'base': 'stations',
#   'main': {'temp': 68.04,
#    'pressure': 1013,
#    'humidity': 83,
#    'temp_min': 66,
#    'temp_max': 70},
#   'visibility': 8047,
#   'wind': {'speed': 8.05, 'deg': 280},
#   'clouds': {'all': 90},
#   'dt': 1554569622,
#   'sys': {'type': 1,
#    'id': 5990,
#    'message': 0.0054,
#    'country': 'US',
#    'sunrise': 1554553210,
#    'sunset': 1554598694},
#   'id': 4696310,
#   'name': 'Harper',
#   'cod': 200},
#  {'coord': {'lon': -76.2, 'lat': -13.71},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 71.6,
#    'pressure': 1014,
#    'humidity': 30,
#    'temp_min': 71.6,
#    'temp_max': 71.6},
#   'visibility': 10000,
#   'wind': {'speed': 8.05, 'deg': 290},
#   'clouds': {'all': 75},
#   'dt': 1554566400,
#   'sys': {'type': 1,
#    'id': 8691,
#    'message': 0.0043,
#    'country': 'PE',
#    'sunrise': 1554548995,
#    'sunset': 1554591852},
#   'id': 3932145,
#   'name': 'Pisco',
#   'cod': 200},
#  {'coord': {'lon': 102.47, 'lat': 71.98},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 22.73,
#    'pressure': 996.54,
#    'humidity': 84,
#    'temp_min': 22.73,
#    'temp_max': 22.73,
#    'sea_level': 996.54,
#    'grnd_level': 991.74},
#   'wind': {'speed': 11.21, 'deg': 177.004},
#   'clouds': {'all': 48},
#   'dt': 1554568901,
#   'sys': {'message': 0.004,
#    'country': 'RU',
#    'sunrise': 1554500545,
#    'sunset': 1554554558},
#   'id': 2022572,
#   'name': 'Khatanga',
#   'cod': 200},
#  {'coord': {'lon': 138.6, 'lat': -33.21},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 43.7,
#    'pressure': 1019.06,
#    'humidity': 82,
#    'temp_min': 43.7,
#    'temp_max': 43.7,
#    'sea_level': 1019.06,
#    'grnd_level': 960.62},
#   'wind': {'speed': 2.15, 'deg': 37.504},
#   'clouds': {'all': 0},
#   'dt': 1554569104,
#   'sys': {'message': 0.004,
#    'country': 'AU',
#    'sunrise': 1554584463,
#    'sunset': 1554626066},
#   'id': 2069194,
#   'name': 'Jamestown',
#   'cod': 200},
#  {'coord': {'lon': 24.53, 'lat': -32.25},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 60.08,
#    'pressure': 1016.3,
#    'humidity': 60,
#    'temp_min': 60.08,
#    'temp_max': 60.08,
#    'sea_level': 1016.3,
#    'grnd_level': 920.14},
#   'wind': {'speed': 5.39, 'deg': 148.504},
#   'clouds': {'all': 0},
#   'dt': 1554569479,
#   'sys': {'message': 0.0033,
#    'country': 'ZA',
#    'sunrise': 1554525377,
#    'sunset': 1554567129},
#   'id': 1000543,
#   'name': 'Graaff-Reinet',
#   'cod': 200},
#  {'coord': {'lon': -96.99, 'lat': 50.56},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 34,
#    'pressure': 1020,
#    'humidity': 79,
#    'temp_min': 34,
#    'temp_max': 34},
#   'wind': {'speed': 7, 'deg': 96, 'gust': 4.02},
#   'clouds': {'all': 64},
#   'dt': 1554569115,
#   'sys': {'type': 3,
#    'id': 19218,
#    'message': 0.0041,
#    'country': 'CA',
#    'sunrise': 1554551598,
#    'sunset': 1554599226},
#   'id': 5961417,
#   'name': 'Husavik',
#   'cod': 200},
#  {'coord': {'lon': 172.79, 'lat': 3.07},
#   'weather': [{'id': 501,
#     'main': 'Rain',
#     'description': 'moderate rain',
#     'icon': '10n'}],
#   'base': 'stations',
#   'main': {'temp': 79.25,
#    'pressure': 1009.86,
#    'humidity': 100,
#    'temp_min': 79.25,
#    'temp_max': 79.25,
#    'sea_level': 1009.86,
#    'grnd_level': 1009.74},
#   'wind': {'speed': 6.51, 'deg': 44.004},
#   'rain': {'3h': 3.7275},
#   'clouds': {'all': 92},
#   'dt': 1554569125,
#   'sys': {'message': 0.0043,
#    'country': 'KI',
#    'sunrise': 1554575175,
#    'sunset': 1554618946},
#   'id': 2110227,
#   'name': 'Butaritari',
#   'cod': 200},
#  {'coord': {'lon': -94.76, 'lat': 39.95},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 67.59,
#    'pressure': 1014,
#    'humidity': 39,
#    'temp_min': 66,
#    'temp_max': 69.01},
#   'visibility': 16093,
#   'wind': {'speed': 13.87, 'deg': 170, 'gust': 8.2},
#   'clouds': {'all': 1},
#   'dt': 1554569009,
#   'sys': {'type': 1,
#    'id': 4022,
#    'message': 0.0039,
#    'country': 'US',
#    'sunrise': 1554551711,
#    'sunset': 1554598043},
#   'id': 4407665,
#   'name': 'Kodiak',
#   'cod': 200},
#  {'coord': {'lon': -127.42, 'lat': 50.7},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 46.4,
#    'pressure': 991,
#    'humidity': 81,
#    'temp_min': 46.4,
#    'temp_max': 46.4},
#   'visibility': 32186,
#   'wind': {'speed': 21.92, 'deg': 110, 'gust': 18.5},
#   'clouds': {'all': 75},
#   'dt': 1554566400,
#   'sys': {'type': 1,
#    'id': 1011,
#    'message': 0.0046,
#    'country': 'CA',
#    'sunrise': 1554558879,
#    'sunset': 1554606548},
#   'id': 6111862,
#   'name': 'Port Hardy',
#   'cod': 200},
#  {'coord': {'lon': 54.1, 'lat': 17.01},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02n'}],
#   'base': 'stations',
#   'main': {'temp': 82.4,
#    'pressure': 1013,
#    'humidity': 74,
#    'temp_min': 82.4,
#    'temp_max': 82.4},
#   'visibility': 10000,
#   'wind': {'speed': 8.05, 'deg': 190},
#   'clouds': {'all': 20},
#   'dt': 1554565800,
#   'sys': {'type': 1,
#    'id': 7562,
#    'message': 0.0032,
#    'country': 'OM',
#    'sunrise': 1554516884,
#    'sunset': 1554561431},
#   'id': 286621,
#   'name': 'Salalah',
#   'cod': 200},
#  {'cod': '404', 'message': 'city not found'},
#  {'coord': {'lon': 20.32, 'lat': 45.52},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 53.96,
#    'pressure': 1006,
#    'humidity': 44,
#    'temp_min': 48.99,
#    'temp_max': 60.8},
#   'visibility': 10000,
#   'wind': {'speed': 13.87, 'deg': 70},
#   'clouds': {'all': 0},
#   'dt': 1554569228,
#   'sys': {'type': 1,
#    'id': 7030,
#    'message': 0.0037,
#    'country': 'RS',
#    'sunrise': 1554523820,
#    'sunset': 1554570707},
#   'id': 788040,
#   'name': 'Melenci',
#   'cod': 200},
#  {'coord': {'lon': 8.12, 'lat': 52.66},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 64.24,
#    'pressure': 1005,
#    'humidity': 59,
#    'temp_min': 62.01,
#    'temp_max': 68},
#   'visibility': 10000,
#   'wind': {'speed': 4.7, 'deg': 80},
#   'clouds': {'all': 0},
#   'dt': 1554569653,
#   'sys': {'type': 1,
#    'id': 1871,
#    'message': 0.011,
#    'country': 'DE',
#    'sunrise': 1554526247,
#    'sunset': 1554574134},
#   'id': 2936881,
#   'name': 'Dinklage',
#   'cod': 200},
#  {'coord': {'lon': 26.92, 'lat': -6.05},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 77.45,
#    'pressure': 1006.3,
#    'humidity': 85,
#    'temp_min': 77.45,
#    'temp_max': 77.45,
#    'sea_level': 1006.3,
#    'grnd_level': 940.14},
#   'wind': {'speed': 4.38, 'deg': 359.004},
#   'clouds': {'all': 32},
#   'dt': 1554569704,
#   'sys': {'message': 0.0033,
#    'country': 'CD',
#    'sunrise': 1554524039,
#    'sunset': 1554567320},
#   'id': 215668,
#   'name': 'Kabalo',
#   'cod': 200},
#  {'cod': '404', 'message': 'city not found'},
#  {'coord': {'lon': -28.7, 'lat': 38.52},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 62.6,
#    'pressure': 1017,
#    'humidity': 82,
#    'temp_min': 62.6,
#    'temp_max': 62.6},
#   'visibility': 10000,
#   'wind': {'speed': 23.04, 'deg': 250},
#   'clouds': {'all': 40},
#   'dt': 1554566400,
#   'sys': {'type': 1,
#    'id': 6883,
#    'message': 0.0047,
#    'country': 'PT',
#    'sunrise': 1554535943,
#    'sunset': 1554582108},
#   'id': 3372707,
#   'name': 'Ribeira Grande',
#   'cod': 200},
#  {'cod': '404', 'message': 'city not found'},
#  {'coord': {'lon': -94.42, 'lat': 30.04},
#   'weather': [{'id': 721,
#     'main': 'Haze',
#     'description': 'haze',
#     'icon': '50d'},
#    {'id': 701, 'main': 'Mist', 'description': 'mist', 'icon': '50d'},
#    {'id': 201,
#     'main': 'Thunderstorm',
#     'description': 'thunderstorm with rain',
#     'icon': '11d'}],
#   'base': 'stations',
#   'main': {'temp': 73.87,
#    'pressure': 1015,
#    'humidity': 88,
#    'temp_min': 70,
#    'temp_max': 77},
#   'visibility': 11265,
#   'wind': {'speed': 5.82, 'deg': 140},
#   'clouds': {'all': 90},
#   'dt': 1554569122,
#   'sys': {'type': 1,
#    'id': 3476,
#    'message': 0.0046,
#    'country': 'US',
#    'sunrise': 1554552064,
#    'sunset': 1554597526},
#   'id': 4732862,
#   'name': 'Nome',
#   'cod': 200},
#  {'coord': {'lon': 149.07, 'lat': -23.58},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 65.3,
#    'pressure': 1018.98,
#    'humidity': 86,
#    'temp_min': 65.3,
#    'temp_max': 65.3,
#    'sea_level': 1018.98,
#    'grnd_level': 996.3},
#   'wind': {'speed': 6.62, 'deg': 91.004},
#   'clouds': {'all': 0},
#   'dt': 1554569124,
#   'sys': {'message': 0.0033,
#    'country': 'AU',
#    'sunrise': 1554581624,
#    'sunset': 1554623880},
#   'id': 2175403,
#   'name': 'Bluff',
#   'cod': 200},
#  {'cod': '404', 'message': 'city not found'},
#  {'coord': {'lon': 57.7, 'lat': -20.41},
#   'weather': [{'id': 521,
#     'main': 'Rain',
#     'description': 'shower rain',
#     'icon': '09n'}],
#   'base': 'stations',
#   'main': {'temp': 77.95,
#    'pressure': 1017,
#    'humidity': 74,
#    'temp_min': 75.99,
#    'temp_max': 80.6},
#   'visibility': 10000,
#   'wind': {'speed': 11.41, 'deg': 130},
#   'clouds': {'all': 75},
#   'dt': 1554568740,
#   'sys': {'type': 1,
#    'id': 2061,
#    'message': 0.0046,
#    'country': 'MU',
#    'sunrise': 1554517044,
#    'sunset': 1554559544},
#   'id': 934322,
#   'name': 'Mahebourg',
#   'cod': 200},
#  {'coord': {'lon': -100.35, 'lat': 18.62},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 84.29,
#    'pressure': 1010.98,
#    'humidity': 25,
#    'temp_min': 84.29,
#    'temp_max': 84.29,
#    'sea_level': 1010.98,
#    'grnd_level': 891.5},
#   'wind': {'speed': 3.04, 'deg': 282.004},
#   'clouds': {'all': 36},
#   'dt': 1554569246,
#   'sys': {'message': 0.0033,
#    'country': 'MX',
#    'sunrise': 1554553882,
#    'sunset': 1554598554},
#   'id': 3981460,
#   'name': 'Coahuayana',
#   'cod': 200},
#  {'coord': {'lon': 147.9, 'lat': 70.62},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 14.45,
#    'pressure': 1020.38,
#    'humidity': 84,
#    'temp_min': 14.45,
#    'temp_max': 14.45,
#    'sea_level': 1020.38,
#    'grnd_level': 1018.14},
#   'wind': {'speed': 7.85, 'deg': 154.004},
#   'clouds': {'all': 88},
#   'dt': 1554568865,
#   'sys': {'message': 0.0036,
#    'country': 'RU',
#    'sunrise': 1554576202,
#    'sunset': 1554629863},
#   'id': 2126123,
#   'name': 'Chokurdakh',
#   'cod': 200},
#  {'coord': {'lon': 5.14, 'lat': 61.99},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'base': 'stations',
#   'main': {'temp': 44.1,
#    'pressure': 1014,
#    'humidity': 70,
#    'temp_min': 39.99,
#    'temp_max': 48.2},
#   'visibility': 10000,
#   'wind': {'speed': 17.22, 'deg': 330},
#   'clouds': {'all': 12},
#   'dt': 1554569404,
#   'sys': {'type': 1,
#    'id': 1616,
#    'message': 0.0039,
#    'country': 'NO',
#    'sunrise': 1554525974,
#    'sunset': 1554575837},
#   'id': 3146487,
#   'name': 'Raudeberg',
#   'cod': 200},
#  {'cod': '404', 'message': 'city not found'},
#  {'coord': {'lon': 115.24, 'lat': 5.28},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 83.62,
#    'pressure': 1012,
#    'humidity': 74,
#    'temp_min': 82.4,
#    'temp_max': 84.2},
#   'visibility': 10000,
#   'wind': {'speed': 4.7, 'deg': 10},
#   'clouds': {'all': 90},
#   'dt': 1554568200,
#   'sys': {'type': 1,
#    'id': 9372,
#    'message': 0.0042,
#    'country': 'BN',
#    'sunrise': 1554588921,
#    'sunset': 1554632818},
#   'id': 1733782,
#   'name': 'Victoria',
#   'cod': 200},
#  {'coord': {'lon': 59.53, 'lat': 22.57},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '02n'}],
#   'base': 'stations',
#   'main': {'temp': 80.6,
#    'pressure': 1011.66,
#    'humidity': 82,
#    'temp_min': 80.6,
#    'temp_max': 80.6,
#    'sea_level': 1011.66,
#    'grnd_level': 981.66},
#   'wind': {'speed': 1.48, 'deg': 266.004},
#   'clouds': {'all': 8},
#   'dt': 1554569706,
#   'sys': {'message': 0.0049,
#    'country': 'OM',
#    'sunrise': 1554515408,
#    'sunset': 1554560302},
#   'id': 286245,
#   'name': 'Sur',
#   'cod': 200},
#  {'coord': {'lon': -87.99, 'lat': 31.44},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 75.99,
#    'pressure': 1018,
#    'humidity': 86,
#    'temp_min': 75.99,
#    'temp_max': 75.99},
#   'wind': {'speed': 1.99, 'deg': 139, 'gust': 3.58},
#   'rain': {'3h': 0.0075000000000003},
#   'clouds': {'all': 64},
#   'dt': 1554568949,
#   'sys': {'type': 3,
#    'id': 2011568,
#    'message': 0.0046,
#    'country': 'US',
#    'sunrise': 1554550467,
#    'sunset': 1554596038},
#   'id': 4069458,
#   'name': 'Wagar',
#   'cod': 200},
#  {'coord': {'lon': 29.09, 'lat': 70.86},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 32,
#    'pressure': 1016.94,
#    'humidity': 100,
#    'temp_min': 32,
#    'temp_max': 32,
#    'sea_level': 1016.94,
#    'grnd_level': 998.3},
#   'wind': {'speed': 10.2, 'deg': 292.504},
#   'clouds': {'all': 80},
#   'dt': 1554569170,
#   'sys': {'message': 0.0047,
#    'country': 'NO',
#    'sunrise': 1554518446,
#    'sunset': 1554571872},
#   'id': 780687,
#   'name': 'Berlevag',
#   'cod': 200},
#  {'coord': {'lon': -42.02, 'lat': -22.97},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 87.85,
#    'pressure': 1012,
#    'humidity': 74,
#    'temp_min': 86,
#    'temp_max': 89.6},
#   'visibility': 10000,
#   'wind': {'speed': 13.87, 'deg': 240},
#   'clouds': {'all': 0},
#   'dt': 1554566400,
#   'sys': {'type': 1,
#    'id': 8326,
#    'message': 0.0045,
#    'country': 'BR',
#    'sunrise': 1554541057,
#    'sunset': 1554583387},
#   'id': 3471451,
#   'name': 'Arraial do Cabo',
#   'cod': 200},
#  {'coord': {'lon': -108.44, 'lat': 54.13},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'base': 'stations',
#   'main': {'temp': 33.8,
#    'pressure': 1006,
#    'humidity': 93,
#    'temp_min': 33.8,
#    'temp_max': 33.8},
#   'visibility': 24140,
#   'wind': {'speed': 16.11, 'deg': 90},
#   'clouds': {'all': 90},
#   'dt': 1554567000,
#   'sys': {'type': 1,
#    'id': 833,
#    'message': 0.005,
#    'country': 'CA',
#    'sunrise': 1554554050,
#    'sunset': 1554602269},
#   'id': 6071421,
#   'name': 'Meadow Lake',
#   'cod': 200},
#  {'coord': {'lon': 146.19, 'lat': 68.54},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 14.27,
#    'pressure': 1019.38,
#    'humidity': 84,
#    'temp_min': 14.27,
#    'temp_max': 14.27,
#    'sea_level': 1019.38,
#    'grnd_level': 1012.14},
#   'wind': {'speed': 3.15, 'deg': 72.504},
#   'clouds': {'all': 80},
#   'dt': 1554569706,
#   'sys': {'message': 0.0039,
#    'country': 'RU',
#    'sunrise': 1554577177,
#    'sunset': 1554629709},
#   'id': 2126785,
#   'name': 'Belaya Gora',
#   'cod': 200},
#  {'cod': '404', 'message': 'city not found'},
#  {'coord': {'lon': 115.24, 'lat': 5.28},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 84.06,
#    'pressure': 1012,
#    'humidity': 79,
#    'temp_min': 84,
#    'temp_max': 84.2},
#   'visibility': 10000,
#   'wind': {'speed': 2.24, 'deg': 50},
#   'clouds': {'all': 75},
#   'dt': 1554564600,
#   'sys': {'type': 1,
#    'id': 9377,
#    'message': 0.004,
#    'country': 'BN',
#    'sunrise': 1554588921,
#    'sunset': 1554632818},
#   'id': 1733782,
#   'name': 'Victoria',
#   'cod': 200},
#  {'coord': {'lon': 18.42, 'lat': -33.93},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 68.83,
#    'pressure': 1014,
#    'humidity': 68,
#    'temp_min': 66.99,
#    'temp_max': 71.01},
#   'visibility': 10000,
#   'wind': {'speed': 11.41, 'deg': 210},
#   'clouds': {'all': 0},
#   'dt': 1554568991,
#   'sys': {'type': 1,
#    'id': 1899,
#    'message': 0.005,
#    'country': 'ZA',
#    'sunrise': 1554526904,
#    'sunset': 1554568535},
#   'id': 3369157,
#   'name': 'Cape Town',
#   'cod': 200},
#  {'coord': {'lon': 168.86, 'lat': -46.19},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 24.17,
#    'pressure': 1024.98,
#    'humidity': 73,
#    'temp_min': 24.17,
#    'temp_max': 24.17,
#    'sea_level': 1024.98,
#    'grnd_level': 1009.5},
#   'wind': {'speed': 2.93, 'deg': 60.504},
#   'clouds': {'all': 0},
#   'dt': 1554569565,
#   'sys': {'message': 0.0032,
#    'country': 'NZ',
#    'sunrise': 1554577761,
#    'sunset': 1554618246},
#   'id': 6201424,
#   'name': 'Mataura',
#   'cod': 200},
#  {'coord': {'lon': 124.89, 'lat': -9.11},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 76.73,
#    'pressure': 1008.74,
#    'humidity': 100,
#    'temp_min': 76.73,
#    'temp_max': 76.73,
#    'sea_level': 1008.74,
#    'grnd_level': 986.3},
#   'wind': {'speed': 1.36, 'deg': 257.504},
#   'clouds': {'all': 0},
#   'dt': 1554569127,
#   'sys': {'message': 0.0037,
#    'country': 'ID',
#    'sunrise': 1554587006,
#    'sunset': 1554630102},
#   'id': 1651103,
#   'name': 'Atambua',
#   'cod': 200},
#  {'coord': {'lon': -62.27, 'lat': -38.72},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 78.89,
#    'pressure': 1013.82,
#    'humidity': 42,
#    'temp_min': 78.89,
#    'temp_max': 78.89,
#    'sea_level': 1013.82,
#    'grnd_level': 1012.06},
#   'wind': {'speed': 16.69, 'deg': 310.504},
#   'clouds': {'all': 0},
#   'dt': 1554569462,
#   'sys': {'message': 0.0037,
#    'country': 'AR',
#    'sunrise': 1554546463,
#    'sunset': 1554587698},
#   'id': 3865086,
#   'name': 'Bahia Blanca',
#   'cod': 200},
#  {'cod': '404', 'message': 'city not found'},
#  {'coord': {'lon': 173.78, 'lat': -35.1},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 52,
#    'pressure': 1016,
#    'humidity': 94,
#    'temp_min': 52,
#    'temp_max': 52},
#   'wind': {'speed': 4.83, 'deg': 219.004},
#   'rain': {'3h': 0.015000000000001},
#   'clouds': {'all': 44},
#   'dt': 1554568385,
#   'sys': {'type': 3,
#    'id': 2012217,
#    'message': 0.0031,
#    'country': 'NZ',
#    'sunrise': 1554576086,
#    'sunset': 1554617559},
#   'id': 2189343,
#   'name': 'Kaeo',
#   'cod': 200},
#  {'coord': {'lon': 169.85, 'lat': -46.28},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 42.01,
#    'pressure': 1023,
#    'humidity': 67,
#    'temp_min': 42.01,
#    'temp_max': 42.01},
#   'wind': {'speed': 5.01, 'deg': 270, 'gust': 3.13},
#   'clouds': {'all': 0},
#   'dt': 1554569058,
#   'sys': {'type': 3,
#    'id': 2000217,
#    'message': 0.0035,
#    'country': 'NZ',
#    'sunrise': 1554577528,
#    'sunset': 1554618004},
#   'id': 2208248,
#   'name': 'Kaitangata',
#   'cod': 200},
#  {'coord': {'lon': 19.24, 'lat': -34.42},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 66.99,
#    'pressure': 1011,
#    'humidity': 73,
#    'temp_min': 66.99,
#    'temp_max': 66.99},
#   'wind': {'speed': 5.99, 'deg': 92, 'gust': 5.81},
#   'clouds': {'all': 0},
#   'dt': 1554569172,
#   'sys': {'type': 3,
#    'id': 2006131,
#    'message': 0.003,
#    'country': 'ZA',
#    'sunrise': 1554526724,
#    'sunset': 1554568321},
#   'id': 3366880,
#   'name': 'Hermanus',
#   'cod': 200},
#  {'cod': '404', 'message': 'city not found'},
#  {'coord': {'lon': -46.05, 'lat': 60.91},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 44.6,
#    'pressure': 1003,
#    'humidity': 26,
#    'temp_min': 44.6,
#    'temp_max': 44.6},
#   'visibility': 10000,
#   'wind': {'speed': 12.75, 'deg': 100, 'gust': 13.4},
#   'clouds': {'all': 75},
#   'dt': 1554565800,
#   'sys': {'type': 1,
#    'id': 47,
#    'message': 0.0051,
#    'country': 'GL',
#    'sunrise': 1554538378,
#    'sunset': 1554588000},
#   'id': 3421719,
#   'name': 'Narsaq',
#   'cod': 200},
#  {'coord': {'lon': 142.8, 'lat': 47.32},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 32,
#    'pressure': 998,
#    'humidity': 91,
#    'temp_min': 32,
#    'temp_max': 32},
#   'visibility': 10000,
#   'wind': {'speed': 13.42, 'deg': 280},
#   'clouds': {'all': 40},
#   'dt': 1554566400,
#   'sys': {'type': 1,
#    'id': 8889,
#    'message': 0.0058,
#    'country': 'RU',
#    'sunrise': 1554580635,
#    'sunset': 1554627878},
#   'id': 2125945,
#   'name': 'Dolinsk',
#   'cod': 200},
#  {'cod': '404', 'message': 'city not found'},
#  {'cod': '404', 'message': 'city not found'},
#  {'coord': {'lon': -156.47, 'lat': 20.89},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 66.4,
#    'pressure': 1017,
#    'humidity': 82,
#    'temp_min': 60.8,
#    'temp_max': 71.01},
#   'visibility': 16093,
#   'wind': {'speed': 6.93, 'deg': 150},
#   'clouds': {'all': 1},
#   'dt': 1554569032,
#   'sys': {'type': 1,
#    'id': 7879,
#    'message': 0.0049,
#    'country': 'US',
#    'sunrise': 1554567270,
#    'sunset': 1554612098},
#   'id': 5847411,
#   'name': 'Kahului',
#   'cod': 200},
#  {'coord': {'lon': 67.8, 'lat': 66.56},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 28.76,
#    'pressure': 1016.22,
#    'humidity': 85,
#    'temp_min': 28.76,
#    'temp_max': 28.76,
#    'sea_level': 1016.22,
#    'grnd_level': 1012.3},
#   'wind': {'speed': 20.6, 'deg': 276.504},
#   'clouds': {'all': 80},
#   'dt': 1554569708,
#   'sys': {'message': 0.0108,
#    'country': 'RU',
#    'sunrise': 1554510221,
#    'sunset': 1554561520},
#   'id': 1512019,
#   'name': 'Aksarka',
#   'cod': 200},
#  {'coord': {'lon': -52.73, 'lat': 47.66},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 37.76,
#    'pressure': 1021,
#    'humidity': 40,
#    'temp_min': 37,
#    'temp_max': 39},
#   'visibility': 24140,
#   'wind': {'speed': 19.46, 'deg': 260, 'gust': 12.9},
#   'clouds': {'all': 90},
#   'dt': 1554568706,
#   'sys': {'type': 1,
#    'id': 998,
#    'message': 0.0048,
#    'country': 'CA',
#    'sunrise': 1554541194,
#    'sunset': 1554588389},
#   'id': 6167817,
#   'name': 'Torbay',
#   'cod': 200},
#  {'cod': '404', 'message': 'city not found'},
#  {'coord': {'lon': 0.53, 'lat': 46.8},
#   'weather': [{'id': 300,
#     'main': 'Drizzle',
#     'description': 'light intensity drizzle',
#     'icon': '09d'}],
#   'base': 'stations',
#   'main': {'temp': 48.96,
#    'pressure': 998,
#    'humidity': 93,
#    'temp_min': 46.4,
#    'temp_max': 51.01},
#   'visibility': 10000,
#   'wind': {'speed': 12.75, 'deg': 180},
#   'clouds': {'all': 90},
#   'dt': 1554569549,
#   'sys': {'type': 1,
#    'id': 6460,
#    'message': 0.0042,
#    'country': 'FR',
#    'sunrise': 1554528484,
#    'sunset': 1554575539},
#   'id': 3026141,
#   'name': 'Chatellerault',
#   'cod': 200},
#  {'coord': {'lon': -61.49, 'lat': -31.25},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 75.56,
#    'pressure': 1020,
#    'humidity': 34,
#    'temp_min': 73,
#    'temp_max': 78.01},
#   'wind': {'speed': 1.01, 'deg': 295, 'gust': 1.34},
#   'clouds': {'all': 0},
#   'dt': 1554569320,
#   'sys': {'type': 3,
#    'id': 2007137,
#    'message': 0.0038,
#    'country': 'AR',
#    'sunrise': 1554545997,
#    'sunset': 1554587790},
#   'id': 3839479,
#   'name': 'Rafaela',
#   'cod': 200},
#  {'coord': {'lon': -90.35, 'lat': -0.74},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 82.24,
#    'pressure': 1013,
#    'humidity': 70,
#    'temp_min': 80.01,
#    'temp_max': 84.2},
#   'visibility': 10000,
#   'wind': {'speed': 9.17, 'deg': 80},
#   'clouds': {'all': 40},
#   'dt': 1554569172,
#   'sys': {'type': 1,
#    'id': 8521,
#    'message': 0.0039,
#    'country': 'EC',
#    'sunrise': 1554552038,
#    'sunset': 1554595599},
#   'id': 3652764,
#   'name': 'Puerto Ayora',
#   'cod': 200},
#  {'coord': {'lon': -60.7, 'lat': -31.62},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 74.98,
#    'pressure': 1016,
#    'humidity': 40,
#    'temp_min': 73.99,
#    'temp_max': 75.99},
#   'wind': {'speed': 1.99, 'deg': 155, 'gust': 3.58},
#   'clouds': {'all': 0},
#   'dt': 1554569091,
#   'sys': {'type': 3,
#    'id': 2008823,
#    'message': 0.0051,
#    'country': 'AR',
#    'sunrise': 1554545820,
#    'sunset': 1554587588},
#   'id': 3836277,
#   'name': 'Santa Fe',
#   'cod': 200},
#  {'coord': {'lon': 122.88, 'lat': -0.91},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 78.98,
#    'pressure': 1009.3,
#    'humidity': 99,
#    'temp_min': 78.98,
#    'temp_max': 78.98,
#    'sea_level': 1009.3,
#    'grnd_level': 993.5},
#   'wind': {'speed': 1.92, 'deg': 285.504},
#   'clouds': {'all': 44},
#   'dt': 1554569709,
#   'sys': {'message': 0.0038,
#    'country': 'ID',
#    'sunrise': 1554587261,
#    'sunset': 1554630812},
#   'id': 1637001,
#   'name': 'Biak',
#   'cod': 200},
#  {'coord': {'lon': 102.64, 'lat': 37.93},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02n'}],
#   'base': 'stations',
#   'main': {'temp': 37.4,
#    'pressure': 1012.22,
#    'humidity': 48,
#    'temp_min': 37.4,
#    'temp_max': 37.4,
#    'sea_level': 1012.22,
#    'grnd_level': 788.78},
#   'wind': {'speed': 4.38, 'deg': 233.504},
#   'clouds': {'all': 24},
#   'dt': 1554569709,
#   'sys': {'message': 0.0184,
#    'country': 'CN',
#    'sunrise': 1554590793,
#    'sunset': 1554636993},
#   'id': 1803936,
#   'name': 'Wuwei',
#   'cod': 200},
#  {'coord': {'lon': 10.65, 'lat': -3.44},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'base': 'stations',
#   'main': {'temp': 81.68,
#    'pressure': 1008.94,
#    'humidity': 93,
#    'temp_min': 81.68,
#    'temp_max': 81.68,
#    'sea_level': 1008.94,
#    'grnd_level': 998.38},
#   'wind': {'speed': 10.65, 'deg': 243.004},
#   'rain': {'3h': 1.015},
#   'clouds': {'all': 76},
#   'dt': 1554569709,
#   'sys': {'message': 0.0039,
#    'country': 'GA',
#    'sunrise': 1554527875,
#    'sunset': 1554571293},
#   'id': 2399001,
#   'name': 'Mayumba',
#   'cod': 200},
#  {'coord': {'lon': 118.58, 'lat': -20.31},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02n'}],
#   'base': 'stations',
#   'main': {'temp': 77,
#    'pressure': 1011,
#    'humidity': 78,
#    'temp_min': 77,
#    'temp_max': 77},
#   'visibility': 10000,
#   'wind': {'speed': 5.82, 'deg': 190},
#   'clouds': {'all': 24},
#   'dt': 1554566400,
#   'sys': {'type': 1,
#    'id': 9585,
#    'message': 0.0039,
#    'country': 'AU',
#    'sunrise': 1554588843,
#    'sunset': 1554631293},
#   'id': 2063042,
#   'name': 'Port Hedland',
#   'cod': 200},
#  {'coord': {'lon': 42.73, 'lat': 38.8},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 42.94,
#    'pressure': 1017,
#    'humidity': 87,
#    'temp_min': 42.8,
#    'temp_max': 43},
#   'visibility': 10000,
#   'wind': {'speed': 3.36, 'deg': 100},
#   'clouds': {'all': 75},
#   'dt': 1554565800,
#   'sys': {'type': 1,
#    'id': 6998,
#    'message': 0.006,
#    'country': 'TR',
#    'sunrise': 1554518805,
#    'sunset': 1554564967},
#   'id': 325336,
#   'name': 'Adilcevaz',
#   'cod': 200},
#  {'coord': {'lon': 147.33, 'lat': -42.88},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 48.56,
#    'pressure': 1014,
#    'humidity': 76,
#    'temp_min': 45,
#    'temp_max': 52},
#   'visibility': 10000,
#   'wind': {'speed': 8.05, 'deg': 330},
#   'clouds': {'all': 0},
#   'dt': 1554569054,
#   'sys': {'type': 1,
#    'id': 9545,
#    'message': 0.0059,
#    'country': 'AU',
#    'sunrise': 1554582768,
#    'sunset': 1554623571},
#   'id': 2163355,
#   'name': 'Hobart',
#   'cod': 200},
#  {'coord': {'lon': 27.85, 'lat': 71.03},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 30.92,
#    'pressure': 1017.3,
#    'humidity': 87,
#    'temp_min': 30.92,
#    'temp_max': 30.92,
#    'sea_level': 1017.3,
#    'grnd_level': 998.14},
#   'wind': {'speed': 9.31, 'deg': 290.504},
#   'clouds': {'all': 88},
#   'dt': 1554569710,
#   'sys': {'message': 0.0066,
#    'country': 'NO',
#    'sunrise': 1554518691,
#    'sunset': 1554572222},
#   'id': 778707,
#   'name': 'Mehamn',
#   'cod': 200},
#  {'cod': '404', 'message': 'city not found'},
#  {'coord': {'lon': 77.67, 'lat': 54.1},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02n'}],
#   'base': 'stations',
#   'main': {'temp': 35.06,
#    'pressure': 1027.06,
#    'humidity': 75,
#    'temp_min': 35.06,
#    'temp_max': 35.06,
#    'sea_level': 1027.06,
#    'grnd_level': 1013.42},
#   'wind': {'speed': 12.1, 'deg': 282.004},
#   'clouds': {'all': 24},
#   'dt': 1554569710,
#   'sys': {'message': 0.0037,
#    'country': 'RU',
#    'sunrise': 1554509462,
#    'sunset': 1554557542},
#   'id': 1511094,
#   'name': 'Bagan',
#   'cod': 200},
#  {'coord': {'lon': -117.13, 'lat': 58.52},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 26.6,
#    'pressure': 1006,
#    'humidity': 68,
#    'temp_min': 26.6,
#    'temp_max': 26.6},
#   'visibility': 24140,
#   'wind': {'speed': 13.87, 'deg': 120},
#   'clouds': {'all': 75},
#   'dt': 1554566400,
#   'sys': {'type': 1,
#    'id': 867,
#    'message': 0.004,
#    'country': 'CA',
#    'sunrise': 1554555692,
#    'sunset': 1554604797},
#   'id': 5975004,
#   'name': 'High Level',
#   'cod': 200},
#  {'coord': {'lon': 90.87, 'lat': 26.5},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'base': 'stations',
#   'main': {'temp': 65.39,
#    'pressure': 1011.62,
#    'humidity': 93,
#    'temp_min': 65.39,
#    'temp_max': 65.39,
#    'sea_level': 1011.62,
#    'grnd_level': 1005.5},
#   'wind': {'speed': 4.94, 'deg': 112.004},
#   'rain': {'3h': 1.4725},
#   'clouds': {'all': 68},
#   'dt': 1554569710,
#   'sys': {'message': 0.0048,
#    'country': 'IN',
#    'sunrise': 1554507759,
#    'sunset': 1554552910},
#   'id': 1255708,
#   'name': 'Sorbhog',
#   'cod': 200},
#  {'coord': {'lon': 80.55, 'lat': 73.51},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 15.89,
#    'pressure': 1001.74,
#    'humidity': 93,
#    'temp_min': 15.89,
#    'temp_max': 15.89,
#    'sea_level': 1001.74,
#    'grnd_level': 1001.42},
#   'wind': {'speed': 7.96, 'deg': 348.504},
#   'clouds': {'all': 64},
#   'dt': 1554569145,
#   'sys': {'message': 0.004,
#    'country': 'RU',
#    'sunrise': 1554505221,
#    'sunset': 1554560401},
#   'id': 1507390,
#   'name': 'Dikson',
#   'cod': 200},
#  {'coord': {'lon': -83.23, 'lat': 15},
#   'weather': [{'id': 521,
#     'main': 'Rain',
#     'description': 'shower rain',
#     'icon': '09d'},
#    {'id': 721, 'main': 'Haze', 'description': 'haze', 'icon': '50d'}],
#   'base': 'stations',
#   'main': {'temp': 84.2,
#    'pressure': 1014,
#    'humidity': 70,
#    'temp_min': 84.2,
#    'temp_max': 84.2},
#   'visibility': 10000,
#   'wind': {'speed': 6.93, 'deg': 20},
#   'clouds': {'all': 40},
#   'dt': 1554566400,
#   'sys': {'type': 1,
#    'id': 7087,
#    'message': 0.0034,
#    'country': 'HN',
#    'sunrise': 1554549887,
#    'sunset': 1554594333},
#   'id': 3608828,
#   'name': 'Iralaya',
#   'cod': 200},
#  {'coord': {'lon': 121.44, 'lat': 17.41},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'base': 'stations',
#   'main': {'temp': 67.64,
#    'pressure': 1012.1,
#    'humidity': 94,
#    'temp_min': 67.64,
#    'temp_max': 67.64,
#    'sea_level': 1012.1,
#    'grnd_level': 921.42},
#   'wind': {'speed': 1.36, 'deg': 223.504},
#   'rain': {'3h': 0.9075},
#   'clouds': {'all': 36},
#   'dt': 1554569711,
#   'sys': {'message': 0.0039,
#    'country': 'PH',
#    'sunrise': 1554587073,
#    'sunset': 1554631691},
#   'id': 1684803,
#   'name': 'Tabuk',
#   'cod': 200},
#  {'coord': {'lon': -139.03, 'lat': -9.8},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 82.76,
#    'pressure': 1012.38,
#    'humidity': 98,
#    'temp_min': 82.76,
#    'temp_max': 82.76,
#    'sea_level': 1012.38,
#    'grnd_level': 1012.38},
#   'wind': {'speed': 17.25, 'deg': 96.504},
#   'clouds': {'all': 32},
#   'dt': 1554569112,
#   'sys': {'message': 0.0034,
#    'country': 'PF',
#    'sunrise': 1554563966,
#    'sunset': 1554607033},
#   'id': 4020109,
#   'name': 'Atuona',
#   'cod': 200},
#  {'coord': {'lon': 170.5, 'lat': -45.87},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 48.99,
#    'pressure': 1026,
#    'humidity': 65,
#    'temp_min': 48.99,
#    'temp_max': 48.99},
#   'wind': {'speed': 5.99, 'deg': 5, 'gust': 5.81},
#   'clouds': {'all': 0},
#   'dt': 1554568770,
#   'sys': {'type': 3,
#    'id': 75281,
#    'message': 0.0041,
#    'country': 'NZ',
#    'sunrise': 1554577350,
#    'sunset': 1554617870},
#   'id': 2191562,
#   'name': 'Dunedin',
#   'cod': 200},
#  {'coord': {'lon': 1.41, 'lat': 18.44},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'base': 'stations',
#   'main': {'temp': 90.05,
#    'pressure': 1008.22,
#    'humidity': 14,
#    'temp_min': 90.05,
#    'temp_max': 90.05,
#    'sea_level': 1008.22,
#    'grnd_level': 956.54},
#   'wind': {'speed': 13, 'deg': 327.504},
#   'clouds': {'all': 24},
#   'dt': 1554569547,
#   'sys': {'message': 0.0035,
#    'country': 'ML',
#    'sunrise': 1554529479,
#    'sunset': 1554574122},
#   'id': 2455290,
#   'name': 'Kidal',
#   'cod': 200},
#  {'coord': {'lon': -45.24, 'lat': 60.14},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 33.62,
#    'pressure': 1005.66,
#    'humidity': 93,
#    'temp_min': 33.62,
#    'temp_max': 33.62,
#    'sea_level': 1005.66,
#    'grnd_level': 993.74},
#   'wind': {'speed': 21.94, 'deg': 113.504},
#   'clouds': {'all': 44},
#   'dt': 1554569212,
#   'sys': {'message': 0.0031,
#    'country': 'GL',
#    'sunrise': 1554538282,
#    'sunset': 1554587707},
#   'id': 3421765,
#   'name': 'Nanortalik',
#   'cod': 200},
#  {'coord': {'lon': 123.37, 'lat': 66.77},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 13.55,
#    'pressure': 1018.82,
#    'humidity': 69,
#    'temp_min': 13.55,
#    'temp_max': 13.55,
#    'sea_level': 1018.82,
#    'grnd_level': 1010.14},
#   'wind': {'speed': 3.15, 'deg': 127.004},
#   'clouds': {'all': 0},
#   'dt': 1554569712,
#   'sys': {'message': 0.0036,
#    'country': 'RU',
#    'sunrise': 1554583038,
#    'sunset': 1554634800},
#   'id': 2012530,
#   'name': 'Zhigansk',
#   'cod': 200},
#  {'coord': {'lon': 132.75, 'lat': -5.67},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 84.02,
#    'pressure': 1009.18,
#    'humidity': 98,
#    'temp_min': 84.02,
#    'temp_max': 84.02,
#    'sea_level': 1009.18,
#    'grnd_level': 1008.62},
#   'wind': {'speed': 4.83, 'deg': 285.504},
#   'clouds': {'all': 48},
#   'dt': 1554569225,
#   'sys': {'message': 0.003,
#    'country': 'ID',
#    'sunrise': 1554585024,
#    'sunset': 1554628312},
#   'id': 1623197,
#   'name': 'Tual',
#   'cod': 200},
#  {'coord': {'lon': -104.67, 'lat': 23.99},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '02d'}],
#   'base': 'stations',
#   'main': {'temp': 61.38,
#    'pressure': 1023,
#    'humidity': 23,
# ...
#    'grnd_level': 949.02},
#   'wind': {'speed': 2.71, 'deg': 23.004},
#   'clouds': {'all': 56},
#   'dt': 1554569786,
#   'sys': {'message': 0.0033,
#    'country': 'RU',
#    'sunrise': 1554582991,
#    'sunset': 1554630624},
#   'id': 2014694,
#   'name': 'Tyrma',
#   'cod': 200},
#  {'coord': {'lon': -77.04, 'lat': -12.06},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 78.8,
#    'pressure': 1014,
#    'humidity': 69,
#    'temp_min': 78.8,
#    'temp_max': 78.8},
#   'visibility': 10000,
#   'wind': {'speed': 5.82, 'deg': 180},
#   'clouds': {'all': 90},
#   'dt': 1554566400,
#   'sys': {'type': 1,
#    'id': 8682,
#    'message': 0.0036,
#    'country': 'PE',
#    'sunrise': 1554549151,
#    'sunset': 1554592099},
#   'id': 3936456,
#   'name': 'Lima',
#   'cod': 200},
#  {'coord': {'lon': 12.92, 'lat': 18.69},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 90.32,
#    'pressure': 1004.38,
#    'humidity': 12,
#    'temp_min': 90.32,
#    'temp_max': 90.32,
#    'sea_level': 1004.38,
#    'grnd_level': 949.18},
#   'wind': {'speed': 5.06, 'deg': 193.504},
#   'clouds': {'all': 0},
#   'dt': 1554569260,
#   'sys': {'message': 0.0029,
#    'country': 'NE',
#    'sunrise': 1554526711,
#    'sunset': 1554571367},
#   'id': 2446796,
#   'name': 'Bilma',
#   'cod': 200},
#  {'coord': {'lon': -135.01, 'lat': 68.22},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '02d'}],
#   'base': 'stations',
#   'main': {'temp': 5.32,
#    'pressure': 1009,
#    'humidity': 77,
#    'temp_min': 3.2,
#    'temp_max': 6.8},
#   'visibility': 24140,
#   'wind': {'speed': 2.24, 'deg': 130},
#   'clouds': {'all': 5},
#   'dt': 1554566400,
#   'sys': {'type': 1,
#    'id': 821,
#    'message': 0.0045,
#    'country': 'CA',
#    'sunrise': 1554558399,
#    'sunset': 1554610671},
#   'id': 5882953,
#   'name': 'Aklavik',
#   'cod': 200},
#  {'coord': {'lon': 106.21, 'lat': 50.23},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 18.95,
#    'pressure': 1023.54,
#    'humidity': 51,
#    'temp_min': 18.95,
#    'temp_max': 18.95,
#    'sea_level': 1023.54,
#    'grnd_level': 931.74},
#   'wind': {'speed': 5.17, 'deg': 351.004},
#   'clouds': {'all': 0},
#   'dt': 1554569786,
#   'sys': {'message': 0.0045,
#    'country': 'MN',
#    'sunrise': 1554589198,
#    'sunset': 1554636875},
#   'id': 2029156,
#   'name': 'Suhbaatar',
#   'cod': 200},
#  {'coord': {'lon': 131.31, 'lat': 31.65},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 52.97,
#    'pressure': 1010.98,
#    'humidity': 100,
#    'temp_min': 52.97,
#    'temp_max': 52.97,
#    'sea_level': 1010.98,
#    'grnd_level': 995.02},
#   'wind': {'speed': 7.63, 'deg': 258.504},
#   'clouds': {'all': 88},
#   'dt': 1554569787,
#   'sys': {'message': 0.0045,
#    'country': 'JP',
#    'sunrise': 1554584198,
#    'sunset': 1554629829},
#   'id': 1855476,
#   'name': 'Nichinan',
#   'cod': 200},
#  {'coord': {'lon': -39.73, 'lat': -18.59},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 83.93,
#    'pressure': 1012.62,
#    'humidity': 82,
#    'temp_min': 83.93,
#    'temp_max': 83.93,
#    'sea_level': 1012.62,
#    'grnd_level': 1012.14},
#   'wind': {'speed': 10.98, 'deg': 55.504},
#   'clouds': {'all': 0},
#   'dt': 1554569609,
#   'sys': {'message': 0.0033,
#    'country': 'BR',
#    'sunrise': 1554540379,
#    'sunset': 1554582966},
#   'id': 3465769,
#   'name': 'Conceicao da Barra',
#   'cod': 200},
#  {'coord': {'lon': 176.59, 'lat': -39.94},
#   'weather': [{'id': 501,
#     'main': 'Rain',
#     'description': 'moderate rain',
#     'icon': '10n'}],
#   'base': 'stations',
#   'main': {'temp': 42.01,
#    'pressure': 1019,
#    'humidity': 93,
#    'temp_min': 42.01,
#    'temp_max': 42.01},
#   'wind': {'speed': 3.6, 'deg': 273.504},
#   'rain': {'3h': 7.2225},
#   'clouds': {'all': 88},
#   'dt': 1554567036,
#   'sys': {'type': 3,
#    'id': 2010964,
#    'message': 0.0034,
#    'country': 'NZ',
#    'sunrise': 1554575608,
#    'sunset': 1554616690},
#   'id': 2185329,
#   'name': 'Waipawa',
#   'cod': 200},
#  {'coord': {'lon': 104.98, 'lat': -5.36},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02n'}],
#   'base': 'stations',
#   'main': {'temp': 75.56,
#    'pressure': 1010.62,
#    'humidity': 85,
#    'temp_min': 75.56,
#    'temp_max': 75.56,
#    'sea_level': 1010.62,
#    'grnd_level': 985.74},
#   'wind': {'speed': 3.71, 'deg': 221.504},
#   'clouds': {'all': 12},
#   'dt': 1554569787,
#   'sys': {'message': 0.0032,
#    'country': 'ID',
#    'sunrise': 1554505289,
#    'sunset': 1554548609},
#   'id': 1630639,
#   'name': 'Pringsewu',
#   'cod': 200},
#  {'cod': '404', 'message': 'city not found'},
#  {'coord': {'lon': -51.74, 'lat': 64.17},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 41,
#    'pressure': 1001,
#    'humidity': 44,
#    'temp_min': 41,
#    'temp_max': 41},
#   'visibility': 10000,
#   'wind': {'speed': 13.87, 'deg': 100},
#   'clouds': {'all': 75},
#   'dt': 1554568932,
#   'sys': {'type': 1,
#    'id': 86,
#    'message': 0.0042,
#    'country': 'GL',
#    'sunrise': 1554539264,
#    'sunset': 1554589845},
#   'id': 3421319,
#   'name': 'Nuuk',
#   'cod': 200},
#  {'coord': {'lon': 31.32, 'lat': 47.91},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 43.43,
#    'pressure': 1017.66,
#    'humidity': 55,
#    'temp_min': 43.43,
#    'temp_max': 43.43,
#    'sea_level': 1017.66,
#    'grnd_level': 999.9},
#   'wind': {'speed': 6.4, 'deg': 103.504},
#   'clouds': {'all': 0},
#   'dt': 1554569698,
#   'sys': {'message': 0.0032,
#    'country': 'UA',
#    'sunrise': 1554521034,
#    'sunset': 1554568214},
#   'id': 713222,
#   'name': 'Arbuzynka',
#   'cod': 200},
#  {'coord': {'lon': 146.82, 'lat': -19.26},
#   'weather': [{'id': 520,
#     'main': 'Rain',
#     'description': 'light intensity shower rain',
#     'icon': '09n'}],
#   'base': 'stations',
#   'main': {'temp': 72.57,
#    'pressure': 1016,
#    'humidity': 94,
#    'temp_min': 72,
#    'temp_max': 73.4},
#   'visibility': 8000,
#   'wind': {'speed': 5.82, 'deg': 70},
#   'clouds': {'all': 90},
#   'dt': 1554569121,
#   'sys': {'type': 1,
#    'id': 9508,
#    'message': 0.0034,
#    'country': 'AU',
#    'sunrise': 1554582033,
#    'sunset': 1554624551},
#   'id': 2146142,
#   'name': 'Townsville',
#   'cod': 200},
#  {'coord': {'lon': 74.49, 'lat': 65.85},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 29.57,
#    'pressure': 1012.18,
#    'humidity': 93,
#    'temp_min': 29.57,
#    'temp_max': 29.57,
#    'sea_level': 1012.18,
#    'grnd_level': 1004.86},
#   'wind': {'speed': 19.93, 'deg': 293.004},
#   'clouds': {'all': 92},
#   'dt': 1554569788,
#   'sys': {'message': 0.003,
#    'country': 'RU',
#    'sunrise': 1554508755,
#    'sunset': 1554559776},
#   'id': 1495626,
#   'name': 'Pangody',
#   'cod': 200},
#  {'coord': {'lon': 33.19, 'lat': -4.22},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'base': 'stations',
#   'main': {'temp': 71.15,
#    'pressure': 1007.18,
#    'humidity': 74,
#    'temp_min': 71.15,
#    'temp_max': 71.15,
#    'sea_level': 1007.18,
#    'grnd_level': 880.14},
#   'wind': {'speed': 4.05, 'deg': 215.504},
#   'rain': {'3h': 0.4725},
#   'clouds': {'all': 44},
#   'dt': 1554569788,
#   'sys': {'message': 0.003,
#    'country': 'TZ',
#    'sunrise': 1554522486,
#    'sunset': 1554565864},
#   'id': 150930,
#   'name': 'Nzega',
#   'cod': 200},
#  {'coord': {'lon': 25.97, 'lat': 70.98},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 31.82,
#    'pressure': 1017.94,
#    'humidity': 98,
#    'temp_min': 31.82,
#    'temp_max': 31.82,
#    'sea_level': 1017.94,
#    'grnd_level': 1002.78},
#   'wind': {'speed': 9.19, 'deg': 290.004},
#   'clouds': {'all': 80},
#   'dt': 1554569788,
#   'sys': {'message': 0.0038,
#    'country': 'NO',
#    'sunrise': 1554519156,
#    'sunset': 1554572659},
#   'id': 779554,
#   'name': 'Honningsvag',
#   'cod': 200},
#  {'coord': {'lon': 0.98, 'lat': 8.56},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 86.45,
#    'pressure': 1007.18,
#    'humidity': 63,
#    'temp_min': 86.45,
#    'temp_max': 86.45,
#    'sea_level': 1007.18,
#    'grnd_level': 972.86},
#   'wind': {'speed': 3.27, 'deg': 237.004},
#   'clouds': {'all': 36},
#   'dt': 1554569788,
#   'sys': {'message': 0.0036,
#    'country': 'TG',
#    'sunrise': 1554529871,
#    'sunset': 1554573937},
#   'id': 2364079,
#   'name': 'Sotouboua',
#   'cod': 200},
#  {'coord': {'lon': 46.6, 'lat': -21.17},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 67.55,
#    'pressure': 1017.5,
#    'humidity': 80,
#    'temp_min': 67.55,
#    'temp_max': 67.55,
#    'sea_level': 1017.5,
#    'grnd_level': 878.62},
#   'wind': {'speed': 7.07, 'deg': 74.004},
#   'clouds': {'all': 36},
#   'dt': 1554569788,
#   'sys': {'message': 0.0032,
#    'country': 'MG',
#    'sunrise': 1554519730,
#    'sunset': 1554562185},
#   'id': 1064258,
#   'name': 'Ikalamavony',
#   'cod': 200},
#  {'coord': {'lon': 70.83, 'lat': 66.83},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 29.84,
#    'pressure': 1013.42,
#    'humidity': 84,
#    'temp_min': 29.84,
#    'temp_max': 29.84,
#    'sea_level': 1013.42,
#    'grnd_level': 1012.3},
#   'wind': {'speed': 24.96, 'deg': 281.004},
#   'clouds': {'all': 80},
#   'dt': 1554569206,
#   'sys': {'message': 0.0039,
#    'country': 'RU',
#    'sunrise': 1554509443,
#    'sunset': 1554560844},
#   'id': 1486321,
#   'name': 'Yar-Sale',
#   'cod': 200},
#  {'coord': {'lon': 50.26, 'lat': 44.51},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 52.43,
#    'pressure': 1018.82,
#    'humidity': 79,
#    'temp_min': 52.43,
#    'temp_max': 52.43,
#    'sea_level': 1018.82,
#    'grnd_level': 1015.26},
#   'wind': {'speed': 5.73, 'deg': 104.004},
#   'clouds': {'all': 64},
#   'dt': 1554569789,
#   'sys': {'message': 0.0041,
#    'country': 'KZ',
#    'sunrise': 1554516702,
#    'sunset': 1554563456},
#   'id': 609906,
#   'name': 'Fort-Shevchenko',
#   'cod': 200},
#  {'coord': {'lon': 20.38, 'lat': 52.62},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 60.42,
#    'pressure': 1010,
#    'humidity': 31,
#    'temp_min': 59,
#    'temp_max': 62.6},
#   'visibility': 10000,
#   'wind': {'speed': 13.87, 'deg': 100},
#   'clouds': {'all': 0},
#   'dt': 1554569720,
#   'sys': {'type': 1,
#    'id': 1708,
#    'message': 0.0039,
#    'country': 'PL',
#    'sunrise': 1554523313,
#    'sunset': 1554571185},
#   'id': 762021,
#   'name': 'Plonsk',
#   'cod': 200},
#  {'coord': {'lon': -61.86, 'lat': 47.38},
#   'weather': [{'id': 620,
#     'main': 'Snow',
#     'description': 'light shower snow',
#     'icon': '13d'}],
#   'base': 'stations',
#   'main': {'temp': 32,
#    'pressure': 1015,
#    'humidity': 89,
#    'temp_min': 32,
#    'temp_max': 32},
#   'visibility': 12874,
#   'wind': {'speed': 17.22, 'deg': 210, 'gust': 11.8},
#   'clouds': {'all': 90},
#   'dt': 1554566400,
#   'sys': {'type': 1,
#    'id': 799,
#    'message': 0.0033,
#    'country': 'CA',
#    'sunrise': 1554543401,
#    'sunset': 1554590564},
#   'id': 5915327,
#   'name': 'Cap-aux-Meules',
#   'cod': 200},
#  {'coord': {'lon': 129.55, 'lat': -14.25},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 77.99,
#    'pressure': 1009.38,
#    'humidity': 97,
#    'temp_min': 77.99,
#    'temp_max': 77.99,
#    'sea_level': 1009.38,
#    'grnd_level': 1004.3},
#   'wind': {'speed': 7.74, 'deg': 25.004},
#   'clouds': {'all': 88},
#   'dt': 1554569789,
#   'sys': {'message': 0.004,
#    'country': 'AU',
#    'sunrise': 1554586032,
#    'sunset': 1554628840},
#   'id': 2063039,
#   'name': 'Port Keats',
#   'cod': 200},
#  {'cod': '404', 'message': 'city not found'},
#  {'coord': {'lon': 31.8, 'lat': 68.61},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 37.4,
#    'pressure': 1018,
#    'humidity': 55,
#    'temp_min': 37.4,
#    'temp_max': 37.4},
#   'visibility': 10000,
#   'wind': {'speed': 4.47, 'deg': 250},
#   'clouds': {'all': 0},
#   'dt': 1554568200,
#   'sys': {'type': 1,
#    'id': 8927,
#    'message': 0.0032,
#    'country': 'RU',
#    'sunrise': 1554518395,
#    'sunset': 1554570622},
#   'id': 475469,
#   'name': 'Verkhnetulomskiy',
#   'cod': 200},
#  {'cod': '404', 'message': 'city not found'},
#  {'cod': '404', 'message': 'city not found'},
#  {'coord': {'lon': 114.62, 'lat': -8.36},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 78.62,
#    'pressure': 1010.3,
#    'humidity': 100,
#    'temp_min': 78.62,
#    'temp_max': 78.62,
#    'sea_level': 1010.3,
#    'grnd_level': 998.54},
#   'wind': {'speed': 3.83, 'deg': 196.004},
#   'clouds': {'all': 80},
#   'dt': 1554569790,
#   'sys': {'message': 0.0037,
#    'country': 'ID',
#    'sunrise': 1554589450,
#    'sunset': 1554632587},
#   'id': 1634266,
#   'name': 'Negara',
#   'cod': 200},
#  {'coord': {'lon': 27.62, 'lat': 2.77},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02n'}],
#   'base': 'stations',
#   'main': {'temp': 77.27,
#    'pressure': 1007.1,
#    'humidity': 73,
#    'temp_min': 77.27,
#    'temp_max': 77.27,
#    'sea_level': 1007.1,
#    'grnd_level': 924.38},
#   'wind': {'speed': 2.71, 'deg': 26.504},
#   'clouds': {'all': 24},
#   'dt': 1554569790,
#   'sys': {'message': 0.0039,
#    'country': 'CD',
#    'sunrise': 1554523637,
#    'sunset': 1554567386},
#   'id': 215771,
#   'name': 'Isiro',
#   'cod': 200},
#  {'cod': '404', 'message': 'city not found'},
#  {'coord': {'lon': 147.14, 'lat': -41.43},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02n'}],
#   'base': 'stations',
#   'main': {'temp': 48.78,
#    'pressure': 1015,
#    'humidity': 87,
#    'temp_min': 44.6,
#    'temp_max': 52},
#   'visibility': 10000,
#   'wind': {'speed': 8.05, 'deg': 340},
#   'clouds': {'all': 20},
#   'dt': 1554569763,
#   'sys': {'type': 1,
#    'id': 9549,
#    'message': 0.0039,
#    'country': 'AU',
#    'sunrise': 1554582746,
#    'sunset': 1554623684},
#   'id': 2160517,
#   'name': 'Launceston',
#   'cod': 200},
#  {'coord': {'lon': 29.46, 'lat': -25.77},
#   'weather': [{'id': 501,
#     'main': 'Rain',
#     'description': 'moderate rain',
#     'icon': '10n'}],
#   'base': 'stations',
#   'main': {'temp': 55.85,
#    'pressure': 1018.18,
#    'humidity': 98,
#    'temp_min': 55.85,
#    'temp_max': 55.85,
#    'sea_level': 1018.18,
#    'grnd_level': 853.42},
#   'wind': {'speed': 3.27, 'deg': 149.004},
#   'rain': {'3h': 4.2525},
#   'clouds': {'all': 76},
#   'dt': 1554569791,
#   'sys': {'message': 0.0029,
#    'country': 'ZA',
#    'sunrise': 1554523982,
#    'sunset': 1554566158},
#   'id': 976361,
#   'name': 'Middelburg',
#   'cod': 200},
#  {'coord': {'lon': -25.58, 'lat': 37.8},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'base': 'stations',
#   'main': {'temp': 62.6,
#    'pressure': 1018,
#    'humidity': 77,
#    'temp_min': 62.6,
#    'temp_max': 62.6},
#   'visibility': 10000,
#   'wind': {'speed': 20.8, 'deg': 250},
#   'clouds': {'all': 20},
#   'dt': 1554568200,
#   'sys': {'type': 1,
#    'id': 6899,
#    'message': 0.0038,
#    'country': 'PT',
#    'sunrise': 1554535229,
#    'sunset': 1554581325},
#   'id': 3372745,
#   'name': 'Rabo de Peixe',
#   'cod': 200}]

# %%
# placeholder dataframe
weather_dict = {"City":cities}
weather_data = pd.DataFrame(weather_dict)

weather_data["Cloudiness"] = ""
weather_data["Country"] = ""
weather_data["Date"] = ""
weather_data["Humidity"] = ""
weather_data["Lat"] = ""
weather_data["Lng"] = ""
weather_data["Max Temp"] = ""
weather_data["Wind Speed"] = ""

weather_data.head()
# Out:
#                   City Cloudiness Country Date Humidity Lat Lng Max Temp  \
# 0             zharkent
# 1             hamilton
# 2  minas de barroteran
# 3             thompson
# 4               hearst
#
#   Wind Speed
# 0
# 1
# 2
# 3
# 4

# %%
# Loop through the list of cities and add data to the dataframe from the json
for index, row in weather_data.iterrows():
    
        #define city in the context of the dataframe
        city = row["City"]
        
        # Build query URL
        query_url = f"{url}appid={api_key}&q={city}&units={units}"

        # Get one of the responses
        post_response = requests.get(query_url)

        # Save response's as JSON
        weather_json = post_response.json()
    
        #Add to dataframe
        try:
            weather_data.loc[index, "Cloudiness"] = weather_json["clouds"]["all"]
            weather_data.loc[index, "Country"] = weather_json["sys"]["country"]
            weather_data.loc[index, "Date"] = weather_json["dt"]
            weather_data.loc[index, "Humidity"] = weather_json["main"]["humidity"]
            weather_data.loc[index, "Lat"] = weather_json["coord"]["lat"]
            weather_data.loc[index, "Lng"] = weather_json["coord"]["lon"]
            weather_data.loc[index, "Max Temp"] = weather_json["main"]["temp_max"]
            weather_data.loc[index, "Wind Speed"] = weather_json["wind"]["speed"]
        except(KeyError, IndexError):
            print("Missing field/result... skipping.")
# Out:
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.

# %%
weather_data
# Out:
#                 City Cloudiness Country        Date Humidity    Lat     Lng  \
# 0          kokorevka          0      RU  1554160460       61  52.59   34.27
# 1            mataura         92      NZ  1554160205       77 -46.19  168.86
# 2           saleaula
# 3          bathsheba         20      BB  1554156000       69  13.22  -59.52
# 4            kushima         20      JP  1554160345       61   31.5  131.29
# 5           souillac         76      FR  1554160247       87   45.6    -0.6
# 6       punta arenas         90      CL  1554160346       93 -53.16  -70.91
# 7         toora-khem         44      RU  1554160461       77  52.47   96.11
# 8              kapaa         20      US  1554160408       65  22.08 -159.32
# 9          jamestown          0      AU  1554160462       69 -33.21   138.6
# 10   bambous virieux         40      MU  1554160441       88 -20.34   57.76
# 11            beloha          0      MG  1554160462       89 -25.17   45.06
# 12      puerto ayora         20      EC  1554159608       70  -0.74  -90.35
# 13    saint-augustin          0      FR  1554160158       76  44.83   -0.61
# 14             pevek          0      RU  1554160462       81   69.7  170.27
# 15       barentsburg
# 16           rikitea          0      PF  1554160463      100 -23.12 -134.97
# 17          buraydah         40      SA  1554156000       36  26.33   43.97
# 18     mar del plata          0      AR  1554160463       57 -46.43  -67.52
# 19             bluff          0      AU  1554160463       53 -23.58  149.07
# 20            albany          1      US  1554160322       32  42.65  -73.75
# 21            castro         90      CL  1554156000      100 -42.48  -73.76
# 22          goderich         68      CA  1554160306       72  43.74  -81.71
# 23      batemans bay          0      AU  1554160002       74 -35.71  150.18
# 24             sitka          0      US  1554156968       38  37.17  -99.65
# 25      bogorodskoye         56      RU  1554160465       70  52.37  140.44
# 26            yulara          0      AU  1554156000       35 -25.24  130.99
# 27          bulawayo          0      ZW  1554160465       63 -20.16   28.59
# 28         cape town          0      ZA  1554160391       54 -33.93   18.42
# 29            shingu         20      JP  1554158400      100  33.72  135.99
# ..               ...        ...     ...         ...      ...    ...     ...
# 598          maturin          0      VE  1554160572       50   9.75  -63.18
# 599         kirakira         76      SB  1554160572      100 -10.46  161.92
# 600         olafsvik
# 601          samarai         92      PG  1554160573      100 -10.62  150.67
# 602          husavik         32      CA  1554160525       55  50.56  -96.99
# 603        mananjary          8      MG  1554160573       92 -19.16    46.8
# 604            kohlu          8      PK  1554160573       48   29.9   69.25
# 605             juba          0      EE  1554160269       74  57.82   26.93
# 606        dalbandin         12      PK  1554160574       45   28.9   64.41
# 607         tsihombe
# 608              bud         44      NO  1554160562       59  62.91    6.91
# 609         camacupa          0      AO  1554160574       70 -12.02   17.48
# 610       turukhansk         68      RU  1554160574       94   65.8   87.96
# 611           hihifo
# 612           chagda
# 613          gravdal         24      NO  1554160542       69  59.79    5.78
# 614        iskateley         88      RU  1554160575       88  67.68   53.15
# 615          kurchum          0      KZ  1554160575       80  48.57   83.65
# 616        kastamonu         92      TR  1554160318       92  41.38   33.78
# 617       torrington         40      US  1554160512       42  42.06 -104.18
# 618          formosa         90      AR  1554156000       94 -26.19  -58.17
# 619          sibolga         32      ID  1554160576       99   1.74   98.78
# 620         balancan
# 621    srednekolymsk         68      RU  1554160576       79  67.46  153.71
# 622           ziyang         64      CN  1554160576       86  30.12  104.65
# 623            ornes          0      FR  1554160562       57  49.25    5.47
# 624            arlit          0      NE  1554160576       34  18.74    7.39
# 625           kaseda         75      JP  1554160345       75  31.42  130.32
# 626            totma          0      RU  1554160577       83  59.98   42.76
# 627             riom          0      FR  1554160325       40  45.89    3.11
#
#     Max Temp Wind Speed
# 0      29.65      10.07
# 1      53.01       5.99
# 2
# 3       78.8      16.11
# 4       48.2       6.93
# 5       53.6       3.36
# 6         50       9.17
# 7      21.55       2.35
# 8       78.8       9.17
# 9      61.69       5.59
# 10     75.99       3.36
# 11     67.09       5.37
# 12      84.2       9.17
# 13     55.99       3.36
# 14     26.23      16.22
# 15
# 16     76.27      14.99
# 17      62.6       6.93
# 18     67.27      26.84
# 19     76.54      12.64
# 20     37.99      12.75
# 21      51.8      14.99
# 22        37         13
# 23        64          3
# 24        61         10
# 25     28.12       3.58
# 26      57.2       6.93
# 27     60.43       5.59
# 28     60.01       20.8
# 29      42.8       3.36
# ..       ...        ...
# 598     84.1       9.17
# 599    83.11      11.18
# 600
# 601    77.89      20.13
# 602       43       5.99
# 603    57.82       2.68
# 604    50.17       2.46
# 605    30.99       8.05
# 606     60.7       5.37
# 607
# 608       41      12.75
# 609    58.54        2.8
# 610     26.5        8.5
# 611
# 612
# 613     39.2       20.8
# 614    26.59      22.93
# 615     33.7       2.91
# 616    28.93       2.57
# 617     55.4      13.87
# 618     69.8        4.7
# 619    67.45       1.12
# 620
# 621    17.05       3.36
# 622    56.11       6.93
# 623       52      10.29
# 624    73.57       3.13
# 625       48        4.7
# 626    19.66       5.93
# 627     53.6       6.93
#
# [628 rows x 9 columns]

# %%
   #Spot check results
    # Build query URL
    city = "kokorevka"  #Picked a random city from results above
        
    query_url = f"{url}appid={api_key}&q={city}&units={units}"

    # Get one of the posts
    post_response = requests.get(query_url)

    # Save post's JSON
    weather_json = post_response.json()
    weather_json
# Out:
# {'coord': {'lon': 34.27, 'lat': 52.59},
#  'weather': [{'id': 802,
#    'main': 'Clouds',
#    'description': 'scattered clouds',
#    'icon': '03n'}],
#  'base': 'stations',
#  'main': {'temp': 41.09,
#   'pressure': 1022.1,
#   'humidity': 57,
#   'temp_min': 41.09,
#   'temp_max': 41.09,
#   'sea_level': 1022.1,
#   'grnd_level': 1000.3},
#  'wind': {'speed': 8.41, 'deg': 82.504},
#  'clouds': {'all': 44},
#  'dt': 1554570488,
#  'sys': {'message': 0.0041,
#   'country': 'RU',
#   'sunrise': 1554519987,
#   'sunset': 1554567845},
#  'id': 546633,
#  'name': 'Kokorevka',
#  'cod': 200}

# %%
#Drop rows that have no data
weather_data["Cloudiness"].replace('', np.nan, inplace=True)
weather_data["Country"].replace('', np.nan, inplace=True)
weather_data["Date"].replace('', np.nan, inplace=True)
weather_data["Humidity"].replace('', np.nan, inplace=True)
weather_data["Lat"].replace('', np.nan, inplace=True)
weather_data["Lng"].replace('', np.nan, inplace=True)
weather_data["Max Temp"].replace('', np.nan, inplace=True)
weather_data["Wind Speed"].replace('', np.nan, inplace=True)
weather_data.dropna(subset=["Cloudiness"], inplace=True)
weather_data
# Out:
#                     City  Cloudiness Country          Date  Humidity    Lat  \
# 0               zharkent        20.0      KZ  1.554570e+09      68.0  44.17
# 1               hamilton        75.0      BM  1.554569e+09      77.0  32.30
# 2    minas de barroteran         0.0      MX  1.554569e+09      38.0  27.63
# 3               thompson        20.0      CA  1.554566e+09      31.0  55.74
# 4                 hearst         0.0      CA  1.554569e+09      58.0  49.69
# 5                  maloy        12.0      ID  1.554570e+09      89.0   1.00
# 6               ahuimanu        75.0      US  1.554570e+09      82.0  21.44
# 7                ushuaia        90.0      AR  1.554566e+09      69.0 -54.81
# 8            yellowknife        75.0      CA  1.554569e+09      60.0  62.45
# 9               nemetker         0.0      HU  1.554570e+09      69.0  46.72
# 10                 ancud        90.0      CL  1.554566e+09      93.0 -41.87
# 11          punta arenas        40.0      CL  1.554569e+09      89.0 -53.16
# 12                 vaini         0.0      IN  1.554570e+09      76.0  15.34
# 13                albany        90.0      US  1.554569e+09      66.0  42.65
# 14                nacala        44.0      MZ  1.554570e+09      92.0 -14.56
# 15                  lebu         0.0      ET  1.554570e+09      59.0   8.96
# 16               rikitea        76.0      PF  1.554570e+09     100.0 -23.12
# 17             hithadhoo        44.0      MV  1.554570e+09     100.0  -0.60
# 18             busselton        76.0      AU  1.554570e+09      53.0 -33.64
# 19                harper        90.0      US  1.554570e+09      83.0  30.30
# 20                 pisco        75.0      PE  1.554566e+09      30.0 -13.71
# 21              khatanga        48.0      RU  1.554570e+09      84.0  71.98
# 22             jamestown         0.0      AU  1.554570e+09      82.0 -33.21
# 23         graaff-reinet         0.0      ZA  1.554569e+09      60.0 -32.25
# 24               husavik        64.0      CA  1.554570e+09      77.0  50.56
# 25            butaritari        92.0      KI  1.554570e+09     100.0   3.07
# 26                kodiak         1.0      US  1.554570e+09      39.0  39.95
# 27            port hardy        75.0      CA  1.554566e+09      81.0  50.70
# 28               salalah        20.0      OM  1.554566e+09      74.0  17.01
# 30               melenci         0.0      RS  1.554569e+09      44.0  45.52
# ..                   ...         ...     ...           ...       ...    ...
# 581                 poum        40.0      MK  1.554568e+09      62.0  41.28
# 582      haines junction        32.0      CA  1.554570e+09      83.0  60.75
# 583                tyrma        56.0      RU  1.554570e+09      80.0  50.04
# 584                 lima        90.0      PE  1.554566e+09      69.0 -12.06
# 585                bilma         0.0      NE  1.554570e+09      12.0  18.69
# 586              aklavik         5.0      CA  1.554566e+09      77.0  68.22
# 587            suhbaatar         0.0      MN  1.554570e+09      51.0  50.23
# 588             nichinan        88.0      JP  1.554570e+09     100.0  31.65
# 589   conceicao da barra         0.0      BR  1.554570e+09      82.0 -18.59
# 590              waipawa        88.0      NZ  1.554567e+09      93.0 -39.94
# 591            pringsewu        12.0      ID  1.554570e+09      85.0  -5.36
# 593                 nuuk        75.0      GL  1.554569e+09      44.0  64.17
# 594            arbuzynka         0.0      UA  1.554570e+09      55.0  47.91
# 595           townsville        90.0      AU  1.554569e+09      94.0 -19.26
# 596              pangody        92.0      RU  1.554570e+09      93.0  65.85
# 597                nzega        44.0      TZ  1.554570e+09      74.0  -4.22
# 598          honningsvag        80.0      NO  1.554570e+09      98.0  70.98
# 599            sotouboua        36.0      TG  1.554570e+09      63.0   8.56
# 600          ikalamavony        36.0      MG  1.554570e+09      80.0 -21.17
# 601             yar-sale        80.0      RU  1.554570e+09      84.0  66.83
# 602      fort-shevchenko        64.0      KZ  1.554570e+09      79.0  44.51
# 603               plonsk         0.0      PL  1.554570e+09      31.0  52.62
# 604       cap-aux-meules        90.0      CA  1.554566e+09      89.0  47.38
# 605           port keats        88.0      AU  1.554570e+09      97.0 -14.25
# 607     verkhnetulomskiy         0.0      RU  1.554568e+09      55.0  68.61
# 610               negara        80.0      ID  1.554570e+09     100.0  -8.36
# 611                isiro        24.0      CD  1.554570e+09      73.0   2.77
# 613           launceston        20.0      AU  1.554570e+09      87.0 -41.43
# 614           middelburg        76.0      ZA  1.554570e+09      98.0 -25.77
# 615        rabo de peixe        20.0      PT  1.554568e+09      77.0  37.80
#
#         Lng  Max Temp  Wind Speed
# 0     80.00     29.12        1.03
# 1    -64.78     70.00       19.46
# 2   -101.28     84.20        5.61
# 3    -97.86     21.20        4.70
# 4    -83.67     32.90        3.71
# 5    118.10     75.20        2.15
# 6   -157.84     66.99        4.61
# 7    -68.31     39.20       23.04
# 8   -114.38     14.00       11.41
# 9     18.76     51.53        2.48
# 10   -73.83     53.60       18.34
# 11   -70.91     48.20       49.44
# 12    74.49     71.24        2.71
# 13   -73.75     51.01        5.95
# 14    40.69     83.30        9.31
# 15    38.73     61.52        7.85
# 16  -134.97     77.27       14.67
# 17    73.08     84.29        6.17
# 18   115.35     54.00       10.42
# 19   -99.24     70.00        8.05
# 20   -76.20     71.60        8.05
# 21   102.47     22.73       11.21
# 22   138.60     43.70        2.15
# 23    24.53     60.08        5.39
# 24   -96.99     35.01        4.00
# 25   172.79     79.25        6.51
# 26   -94.76     69.01       13.87
# 27  -127.42     46.40       21.92
# 28    54.10     82.40        8.05
# 30    20.32     60.80       13.87
# ..      ...       ...         ...
# 581   20.71     53.60        3.36
# 582 -137.51     20.93        2.37
# 583  132.17     21.83        2.71
# 584  -77.04     78.80        5.82
# 585   12.92     90.32        5.06
# 586 -135.01      6.80        2.24
# 587  106.21     18.95        5.17
# 588  131.31     52.97        7.63
# 589  -39.73     83.93       10.98
# 590  176.59     42.01        3.60
# 591  104.98     75.56        3.71
# 593  -51.74     41.00       13.87
# 594   31.32     43.43        6.40
# 595  146.82     73.40        5.82
# 596   74.49     29.57       19.93
# 597   33.19     71.15        4.05
# 598   25.97     31.82        9.19
# 599    0.98     86.45        3.27
# 600   46.60     67.55        7.07
# 601   70.83     29.84       24.96
# 602   50.26     52.43        5.73
# 603   20.38     62.60       13.87
# 604  -61.86     32.00       17.22
# 605  129.55     77.99        7.74
# 607   31.80     37.40        4.47
# 610  114.62     78.62        3.83
# 611   27.62     77.27        2.71
# 613  147.14     52.00        8.05
# 614   29.46     55.85        3.27
# 615  -25.58     62.60       20.80
#
# [556 rows x 9 columns]

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
#assign variables for data
lat = weather_data["Lat"]
maxtemp = weather_data["Max Temp"]

#build the scatter plot
latvtemp = plt.scatter(lat, maxtemp, marker="o", facecolors="darkcyan", edgecolors="black", alpha=0.75)

# Incorporate the other graph properties
plt.grid()
date = pd.Timestamp("today").strftime("%m/%d/%Y")
plt.title(f"City Latitude vs. Max Temperature ({date})")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
# Out:
# Text(0, 0.5, 'Max Temperature (F)')

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
#assign variables for data
lat = weather_data["Lat"]
humidity = weather_data["Humidity"]

#build the scatter plot
latvhumid = plt.scatter(lat, humidity, marker="o", facecolors="darkcyan", edgecolors="black", alpha=0.75)

# Incorporate the other graph properties
plt.grid()
date = pd.Timestamp("today").strftime("%m/%d/%Y")
plt.title(f"City Latitude vs. Humidity ({date})")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
# Out:
# Text(0, 0.5, 'Humidity (%)')

# %%
#Find the outliers with ridiculous humidity in case its junk data (and in case it's the lost city of Atlantis)
weather_data.loc[weather_data["Humidity"]>200]
# Out:
#         City  Cloudiness Country          Date  Humidity   Lat    Lng  \
# 325  iquitos        20.0      PE  1.554566e+09     319.0 -3.75 -73.25
#
#      Max Temp  Wind Speed
# 325      42.8        8.05

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
#assign variables for data
lat = weather_data["Lat"]
cloudiness = weather_data["Cloudiness"]

#build the scatter plot
latvcloud = plt.scatter(lat, cloudiness, marker="o", facecolors="darkcyan", edgecolors="black", alpha=0.75)

# Incorporate the other graph properties
plt.grid()
date = pd.Timestamp("today").strftime("%m/%d/%Y")
plt.title(f"City Latitude vs. Cloudiness ({date})")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
# Out:
# Text(0, 0.5, 'Cloudiness (%)')

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
#assign variables for data
lat = weather_data["Lat"]
wind = weather_data["Wind Speed"]

#build the scatter plot
latvwind = plt.scatter(lat, wind, marker="o", facecolors="darkcyan", edgecolors="black", alpha=0.75)

# Incorporate the other graph properties
plt.grid()
date = pd.Timestamp("today").strftime("%m/%d/%Y")
plt.title(f"City Latitude vs. Wind Speed ({date})")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
# Out:
# Text(0, 0.5, 'Wind Speed (mph)')
